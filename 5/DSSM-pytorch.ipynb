# %%
import json
import sys
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook, tnrange
from collections import Counter, defaultdict
import re
from gensim import models
from os import listdir
from os.path import isfile, join
import pymorphy2

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
folder = '/home/v.gulin/code/questions_data/json1/'
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]

# %%
questions_all = []
for f in onlyfiles:
    questions_all += json.loads(json.load(open(folder + f)))

# %%
questions_train = questions_all

# %%
morphDict = {}
def text_to_tokens(txt):
    txt = txt.lower()
    txt = re.subn('<[a-z\s]*>', '', txt)[0]
    #txt = re.sub('http\w*\s', '', txt)
    r = re.split('(\s|\-|\.|\,)', txt)
    r = (re.subn('[^А-Яа-яA-Za-z\-\.\,\s]', '', _)[0] for _ in r)
    r = [_ for _ in r if len(_)>1 and 'http' not in _]
    result = []
    for w in r:
        if (w not in morphDict):
            morphDict[w] = morph.parse(w)[0].normal_form
        result.append(morphDict[w])
    return result

# %%
text_to_tokens('Мама мыла раму!')
# Out:
# ['мама', 'мыло', 'рам']

# %%
corpus = []
token_counts = Counter()
for q in tqdm_notebook(questions_train):
    corpus.append(text_to_tokens(q['question']))
    for a in q['answers']:   
        r = text_to_tokens(a)
        corpus.append(r)
        token_counts.update(r)
# Out:
# HBox(children=(IntProgress(value=0, max=52143), HTML(value='')))

# %%
min_count = 4

tokens = [w for w, c in token_counts.items() if c > min_count] 
tokens = ["_PAD_", "_UNK_"] + tokens

token_to_id = {t : i for i, t in enumerate(tokens)}

# %%
corpus
# Out:
# [['какой',
#   'документальный',
#   'фильм',
#   'вы',
#   'считать',
#   'самый',
#   'интересный',
#   'качественный'],
#  ['фильм',
#   'дом',
#   'который',
#   'многие',
#   'слышать',
#   'часть',
#   'этот',
#   'многий',
#   'уже',
#   'писать',
#   'да',
#   'он',
#   'запретить',
#   'да',
#   'он',
#   'красить',
#   'потому',
#   'что',
#   'люк',
#   'бессон',
#   'потому',
#   'что',
#   'фотограф',
#   'артюс',
#   'бертран',
#   'потому',
#   'что',
#   'мы',
#   'мочь',
#   'увидеть',
#   'свой',
#   'планет',
#   'сидеть',
#   'маленькая',
#   'комнатушка',
#   'отделать',
#   'по',
#   'европейск',
#   'этот',
#   'фильм',
#   'также',
#   'отделать',
#   'сознание',
#   'заставить',
#   'задуматься',
#   'что',
#   'же',
#   'мы',
#   'делать',
#   'собственный',
#   'дом',
#   'он',
#   'интересный',
#   'свой',
#   'интересный',
#   'ракурс',
#   'собственный',
#   'правдивость',
#   'не',
#   'менее',
#   'прекрасный',
#   'занимательный'],
#  ['манхеттен', 'manhatta', 'сша', 'чарльз', 'шилера', 'половина', 'страндт'],
#  ['зачем',
#   'samsung',
#   'htc',
#   'возвращать',
#   'на',
#   'рынок',
#   'смартфон',
#   'раскладушка'],
#  ['нельзя',
#   'сказать',
#   'чтобы',
#   'они',
#   'что',
#   'то',
#   'возвращать',
#   'на',
#   'рынок',
#   'такой',
#   'смартфон',
#   'популярный',
#   'азия',
#   'ряд',
#   'страна',
#   'частность',
#   'южный',
#   'корея',
#   'япония',
#   'на',
#   'этот',
#   'рынок',
#   'раскладушка',
#   'не',
#   'только',
#   'смартфон',
#   'быть',
#   'есть',
#   'новое',
#   'модель',
#   'это',
#   'форма',
#   'фактор',
#   'выпускаться',
#   'давно',
#   'ежегодно',
#   'высокий',
#   'цена',
#   'также',
#   'неудивительный',
#   'модель',
#   'limited',
#   'edition',
#   'всегда',
#   'быть',
#   'достаточно',
#   'дорогой'],
#  ['такой',
#   'не',
#   'слышать',
#   'но',
#   'быть',
#   'при',
#   'классно',
#   'если',
#   'бы',
#   'создать',
#   'какой',
#   'то',
#   'модель',
#   'раскладушка',
#   'на',
#   'сенсор',
#   'помнить',
#   'ранний',
#   'весь',
#   'мечтать',
#   'раскладушка',
#   'завидовать',
#   'тем',
#   'кто',
#   'она',
#   'есть',
#   'если',
#   'бы',
#   'не',
#   'мода',
#   'на',
#   'айфон',
#   'удовольствие',
#   'ходить',
#   'бы',
#   'так',
#   'что',
#   'пусть',
#   'усовершенствовать',
#   'они',
#   'быть',
#   'круто'],
#  ['когда', 'лёгкий', 'похудеть', 'зимой', 'или', 'летом'],
#  ['лёгкость',
#   'похудение',
#   'зависеть',
#   'от',
#   'сугубо',
#   'личный',
#   'особенность',
#   'кома',
#   'то',
#   'хотеться',
#   'заедать',
#   'зимний',
#   'хандра',
#   'тёплый',
#   'пончик',
#   'какао',
#   'кто',
#   'то',
#   'не',
#   'мочь',
#   'устоять',
#   'перед',
#   'перспектива',
#   'поехать',
#   'на',
#   'пляж',
#   'шашлык',
#   'пиво'],
#  ['я',
#   'простой',
#   'зимой',
#   'летом',
#   'мочь',
#   'догонять',
#   'ночной',
#   'дожор',
#   'потому',
#   'что',
#   'днём',
#   'кусок',
#   'горло',
#   'не',
#   'лезть',
#   'вечером',
#   'по',
#   'холодок',
#   'мгновенно',
#   'хотеться',
#   'напихаться',
#   'ништячка'],
#  ['летом',
#   'разумеется',
#   'намного',
#   'простой',
#   'терморегуляция',
#   'фруктик',
#   'свой',
#   'дело',
#   'сделать',
#   'но',
#   'таки',
#   'вы',
#   'сказать',
#   'я',
#   'удаться',
#   'похудеть',
#   'самый',
#   'разгар',
#   'зима'],
#  ['по',
#   'свой',
#   'опыт',
#   'сказать',
#   'что',
#   'летом',
#   'сбрасывать',
#   'вес',
#   'простой'],
#  ['по',
#   'я',
#   'так',
#   'летом',
#   'конечно',
#   'есть',
#   'не',
#   'так',
#   'хочетсявидеть',
#   'реальный',
#   'стимул',
#   'красивый',
#   'тело',
#   'на',
#   'пляжесам',
#   'только',
#   'такой',
#   'мотивация',
#   'приступить',
#   'похудение',
#   'участвовать',
#   'конкурс',
#   'от',
#   'тнт',
#   'там',
#   'путёвка',
#   'на',
#   'сейшелы',
#   'разыгрываться',
#   'конечно',
#   'захотеть',
#   'выиграть',
#   'похудеть',
#   'куда',
#   'без',
#   'это'],
#  ['если',
#   'вопрос',
#   'задаваться',
#   'именно',
#   'когда',
#   'то',
#   'мой',
#   'точка',
#   'зрение',
#   'здесь',
#   'нужно',
#   'рассматривать',
#   'вторичный',
#   'помеха',
#   'пример',
#   'летом',
#   'я',
#   'практически',
#   'ничто',
#   'не',
#   'отвлекать',
#   'от',
#   'сушка',
#   'зимой',
#   'большой',
#   'количество',
#   'праздниковновый',
#   'год',
#   'день',
#   'рождение',
#   'девушка',
#   'хороший',
#   'друг',
#   'родитель',
#   'etc',
#   'рассматривать',
#   'этот',
#   'точка',
#   'зрение',
#   'летом',
#   'я',
#   'быть',
#   'худеть',
#   'лёгкий',
#   'ибо',
#   'сложный',
#   'сорваться',
#   'но',
#   'зимой',
#   'включаться',
#   'некий',
#   'мотивировать',
#   'сила',
#   'под',
#   'название',
#   'похудеть',
#   'лёт',
#   'так',
#   'что',
#   'зимой',
#   'лёгкий',
#   'сорваться',
#   'но',
#   'мотивация',
#   'большой',
#   'но',
#   'весь',
#   'это',
#   'лишь',
#   'для',
#   'я',
#   'вы',
#   'мочь',
#   'быть',
#   'весь',
#   'иначе'],
#  ['чисто',
#   'логический',
#   'точка',
#   'зрение',
#   'летом',
#   'организм',
#   'не',
#   'запасать',
#   'жир',
#   'для',
#   'согревание',
#   'жир',
#   'не',
#   'только',
#   'для',
#   'эстетический',
#   'составлять',
#   'природа',
#   'он',
#   'предусмотреть',
#   'также',
#   'для',
#   'сохранение',
#   'тепло',
#   'холод',
#   'плюс',
#   'вы',
#   'большой',
#   'двигаться',
#   'на',
#   'улица',
#   'тепло',
#   'можно',
#   'кататься',
#   'на',
#   'велик',
#   'ролик',
#   'да',
#   'просто',
#   'по',
#   'город',
#   'гулять',
#   'не',
#   'сидеть',
#   'грустно',
#   'дом',
#   'чипсик',
#   'перед',
#   'телик',
#   'потому',
#   'что',
#   'на',
#   'улица',
#   'адовый',
#   'холодина',
#   'гололд',
#   'тп'],
#  ['зимой',
#   'если',
#   'выйти',
#   'зимой',
#   'на',
#   'улица',
#   'при',
#   'температура',
#   'от',
#   'то',
#   'организм',
#   'понадобиться',
#   'тепло',
#   'он',
#   'уже',
#   'быть',
#   'израсходовать',
#   'для',
#   'это',
#   'жир',
#   'если',
#   'хотеть',
#   'похудеть',
#   'то',
#   'конечно',
#   'хороший',
#   'начинать',
#   'сразу',
#   'сейчас',
#   'летом'],
#  ['что', 'мочь', 'посоветовать', 'насчта', 'сон', 'засыпание'],
#  ['полюбить',
#   'режим',
#   'приучить',
#   'себя',
#   'ложиться',
#   'один',
#   'то',
#   'же',
#   'время',
#   'даже',
#   'выходной',
#   'тело',
#   'быстро',
#   'это',
#   'привыкнуть',
#   'быть',
#   'хотеть',
#   'спать',
#   'положить',
#   'время',
#   'просыпаться',
#   'один',
#   'то',
#   'же',
#   'время',
#   'оно',
#   'тоже',
#   'привыкнуть',
#   'но',
#   'выходной',
#   'можно',
#   'вволю',
#   'поваляться',
#   'постель'],
#  ['какой',
#   'рассказ',
#   'петрушевский',
#   'или',
#   'другой',
#   'русский',
#   'автор',
#   'по',
#   'настоящий',
#   'страшный'],
#  ['семья',
#   'вурдалак',
#   'толстой',
#   'кристмас',
#   'гурман',
#   'варго',
#   'пожалуйста',
#   'дать',
#   'развернуть',
#   'ответ',
#   'чтобы',
#   'он',
#   'быть',
#   'интересно',
#   'читать',
#   'ответ',
#   'не',
#   'мочь',
#   'быть',
#   'маленький',
#   'знак'],
#  ['не',
#   'читать',
#   'сам',
#   'рассказ',
#   'но',
#   'экранизация',
#   'пелевинский',
#   'синий',
#   'фонарь',
#   'ничто',
#   'страшный',
#   'вполне',
#   'себя',
#   'жуткий',
#   'метафизически',
#   'конечно',
#   'как',
#   'весь',
#   'мэтр'],
#  ['закрываться',
#   'магазин',
#   'нужно',
#   'продать',
#   'из',
#   'он',
#   'весь',
#   'мебель',
#   'напрашиваться',
#   'авить',
#   'но',
#   'мочь',
#   'есть',
#   'какой',
#   'то',
#   'специализировать',
#   'площадка',
#   'для',
#   'продажа'],
#  ['площадка',
#   'конечно',
#   'много',
#   'для',
#   'реализация',
#   'товар',
#   'только',
#   'бы',
#   'успеть',
#   'весь',
#   'сделать',
#   'я',
#   'например',
#   'быть',
#   'подобный',
#   'ситуация',
#   'время',
#   'катастрофически',
#   'не',
#   'быть',
#   'поэтому',
#   'весь',
#   'мебель',
#   'который',
#   'не',
#   'смочь',
#   'реализовать',
#   'прийтись',
#   'банально',
#   'сдать',
#   'на',
#   'утилизация',
#   'спам',
#   'то',
#   'уже',
#   'не',
#   'быть',
#   'время',
#   'ожидать',
#   'пока',
#   'весь',
#   'товар',
#   'купить'],
#  ['отсылка', 'какой', 'фильм', 'присутствовать', 'фильм', 'зелный', 'слоник'],
#  ['никакой',
#   'отсылка',
#   'нет',
#   'зелном',
#   'слоник',
#   'по',
#   'тот',
#   'простой',
#   'причина',
#   'что',
#   'они',
#   'не',
#   'быть',
#   'прописать',
#   'сценарий',
#   'потому',
#   'что',
#   'сценарий',
#   'фильм',
#   'как',
#   'таковой',
#   'не',
#   'быть',
#   'актр',
#   'начинающий',
#   'никто',
#   'не',
#   'известный',
#   'друг',
#   'режисср',
#   'просто',
#   'болтать',
#   'на',
#   'камера',
#   'вс',
#   'что',
#   'придт',
#   'имя',
#   'голова',
#   'тем',
#   'более',
#   'это',
#   'кино',
#   'авторский',
#   'радикальный',
#   'эксцентричный',
#   'взгляд',
#   'басков',
#   'на',
#   'состояние',
#   'российский',
#   'армия',
#   'значит',
#   'никакой',
#   'отсылка',
#   'вставить',
#   'не',
#   'быть',
#   'она',
#   'нужно',
#   'быть',
#   'такой',
#   'вот',
#   'вычурный',
#   'образ',
#   'донести',
#   'до',
#   'зритель',
#   'свой',
#   'мысль',
#   'не',
#   'делать',
#   'оммажа',
#   'поп',
#   'культура',
#   'на',
#   'какой',
#   'нибыть',
#   'лурка',
#   'конечно',
#   'написать',
#   'что',
#   'кино',
#   'это',
#   'наполнить',
#   'отсылка',
#   'философский',
#   'трактат',
#   'древность',
#   'или',
#   'например',
#   'звздной',
#   'война',
#   'но',
#   'вы',
#   'не',
#   'верить'],
#  ['глупость',
#   'ли',
#   'то',
#   'что',
#   'мыслитель',
#   'роден',
#   'сидеть',
#   'неудобный',
#   'для',
#   'раздумье',
#   'поза'],
#  ['для',
#   'тот',
#   'чтобы',
#   'осознавать',
#   'реальность',
#   'необходимый',
#   'осознанный',
#   'страдание',
#   'неудобный',
#   'поза',
#   'необычный',
#   'для',
#   'бытовой',
#   'восприятие',
#   'обет',
#   'например',
#   'молчание',
#   'аскетизм',
#   'пр',
#   'неудобный',
#   'поза',
#   'мозг',
#   'работать',
#   'активно',
#   'на',
#   'диван',
#   'комфорт',
#   'человек',
#   'не',
#   'мыслить',
#   'мы',
#   'думать',
#   'что',
#   'мы',
#   'мыслить',
#   'поэтому',
#   'это',
#   'глубокий',
#   'точный',
#   'тонкий',
#   'проникновение',
#   'быть',
#   'тема',
#   'сущность',
#   'человек'],
#  ['удобство',
#   'ведь',
#   'дело',
#   'вкус',
#   'кто',
#   'то',
#   'любить',
#   'жстковать',
#   'постель',
#   'кто',
#   'то',
#   'пуховый',
#   'перина',
#   'да',
#   'монах',
#   'неспроста',
#   'запираться',
#   'келья',
#   'уходить',
#   'далкий',
#   'монастырь',
#   'без',
#   'комфортабельный',
#   'номер',
#   'выбор',
#   'не',
#   'глупость'],
#  ['можно',
#   'ли',
#   'засудить',
#   'человек',
#   'который',
#   'насильно',
#   'ты',
#   'щекотать',
#   'звучать',
#   'смешно',
#   'но',
#   'по',
#   'суть',
#   'это',
#   'насилие',
#   'принять',
#   'ли',
#   'полиция',
#   'заявление',
#   'или',
#   'просто',
#   'рассмеяться'],
#  ['смотреть',
#   'где',
#   'вы',
#   'жить',
#   'если',
#   'рф',
#   'страна',
#   'евразэс',
#   'или',
#   'африканский',
#   'континент',
#   'до',
#   'суд',
#   'дело',
#   'дойти',
#   'только',
#   'если',
#   'вы',
#   'защекотать',
#   'насмерть',
#   'по',
#   'факт',
#   'смерть',
#   'так',
#   'как',
#   'видимость',
#   'охрана',
#   'право',
#   'на',
#   'жизнь',
#   'они',
#   'весь',
#   'ещё',
#   'имитироваться',
#   'если',
#   'же',
#   'цивилизовать',
#   'страна',
#   'хороший',
#   'адвокат',
#   'можно',
#   'засудить',
#   'за',
#   'угроза',
#   'прикосновение',
#   'вы',
#   'если',
#   'она',
#   'быть',
#   'доказать',
#   'суд'],
#  ['заявление',
#   'полиция',
#   'от',
#   'вы',
#   'должный',
#   'принять',
#   'любой',
#   'хоть',
#   'о',
#   'убийство',
#   'карл',
#   'маркс',
#   'фридрих',
#   'энгельс',
#   'это',
#   'они',
#   'обязанность',
#   'ст',
#   'упк',
#   'рф',
#   'по',
#   'дать',
#   'факт',
#   'произвести',
#   'дознание',
#   'поскольку',
#   'дознаватель',
#   'не',
#   'курс',
#   'кто',
#   'такой',
#   'маркс',
#   'тем',
#   'более',
#   'энгельс',
#   'скорее',
#   'всего',
#   'быть',
#   'отказный',
#   'материал',
#   'за',
#   'отсутствие',
#   'событие',
#   'преступление'],
#  ['по',
#   'закон',
#   'такой',
#   'возможность',
#   'быть',
#   'должный',
#   'ведь',
#   'это',
#   'можно',
#   'приписать',
#   'истязание',
#   'давно',
#   'пора',
#   'ввести',
#   'какой',
#   'то',
#   'ответственность',
#   'для',
#   'весь',
#   'этот',
#   'странный',
#   'человек',
#   'постоянно',
#   'щекотать',
#   'друг',
#   'знакомый'],
#  ['чем',
#   'можно',
#   'ещ',
#   'приготовить',
#   'какао',
#   'несквика',
#   'кроме',
#   'молоко',
#   'сухой',
#   'молоко'],
#  ['на',
#   'дача',
#   'мой',
#   'друг',
#   'кипятить',
#   'вода',
#   'замешивать',
#   'какао',
#   'это',
#   'на',
#   'любитель',
#   'вообще',
#   'начать',
#   'ходить',
#   'тренажрный',
#   'я',
#   'один',
#   'человечек',
#   'подсказать',
#   'рецептможный',
#   'сделать',
#   'вкусный',
#   'йогурт',
#   'ну',
#   'или',
#   'коктельпонадобиться',
#   'чайный',
#   'ложка',
#   'несквика',
#   'столовый',
#   'ложка',
#   'овсяный',
#   'каша',
#   'грамм',
#   'творог',
#   'банан',
#   'мл',
#   'молокавс',
#   'под',
#   'миксер',
#   'получаться',
#   'очень',
#   'даже',
#   'вкусно'],
#  ['почему',
#   'чиновник',
#   'не',
#   'мочь',
#   'решить',
#   'элементарный',
#   'проблема',
#   'мусор',
#   'некогда',
#   'культурный',
#   'столица',
#   'украина',
#   'город',
#   'львов'],
#  ['потому',
#   'что',
#   'уже',
#   'год',
#   'двадцать',
#   'никто',
#   'без',
#   'привязка',
#   'конкретный',
#   'город',
#   'при',
#   'всм',
#   'желание',
#   'не',
#   'смочь',
#   'запустить',
#   'мусороперерабатывающий',
#   'завод',
#   'аналогичный',
#   'европейский',
#   'на',
#   'весь',
#   'копенгаген',
#   'он',
#   'агломерация',
#   'хватать',
#   'один',
#   'например',
#   'обычно',
#   'это',
#   'объясняться',
#   'силой',
#   'местный',
#   'сельский',
#   'громада',
#   'который',
#   'защищать',
#   'свой',
#   'среда',
#   'обитание',
#   'но',
#   'по',
#   'факт',
#   'они',
#   'противодействие',
#   'являться',
#   'лишь',
#   'винтик',
#   'гигантский',
#   'машина'],
#  ['это',
#   'тот',
#   'редкий',
#   'случай',
#   'когда',
#   'виноватый',
#   'сам',
#   'человек',
#   'не',
#   'чиновник',
#   'ведь',
#   'горуправа',
#   'не',
#   'мочь',
#   'просто',
#   'разложить',
#   'мусор',
#   'на',
#   'атом',
#   'верно',
#   'существующий',
#   'формат',
#   'они',
#   'мочь',
#   'либо',
#   'сохранять',
#   'статус',
#   'кво',
#   'вывозить',
#   'тонна',
#   'на',
#   'свалка',
#   'который',
#   'на',
#   'сегодняшний',
#   'день',
#   'просто',
#   'переполнить',
#   'закрытый',
#   'либо',
#   'менять',
#   'ситуация',
#   'они',
#   'менять',
#   'пытаться',
#   'по',
#   'крайний',
#   'мера',
#   'единственный',
#   'решение',
#   'дать',
#   'случай',
#   'становиться',
#   'сортировка',
#   'мусор',
#   'пилотный',
#   'проект',
#   'запустить',
#   'в',
#   'многий',
#   'город',
#   'уже',
#   'не',
#   'один',
#   'год',
#   'где',
#   'то',
#   'уж',
#   'на',
#   'львовский',
#   'власть',
#   'грешить',
#   'по',
#   'благоустройство',
#   'город',
#   'неправильно',
#   'по',
#   'крайний',
#   'мера',
#   'если',
#   'сравнивать',
#   'другой',
#   'украинский',
#   'город'],
#  ['как', 'выстраивать', 'взаимоотношение', 'человек'],
#  ['взаимоотношение',
#   'разный',
#   'бывать',
#   'дружеский',
#   'любовный',
#   'рабочий',
#   'поточный',
#   'бы',
#   'если',
#   'общий',
#   'картина',
#   'отвечать',
#   'то',
#   'деликатно',
#   'более',
#   'менее',
#   'искренне'],
#  ['почему',
#   'фильм',
#   'гарри',
#   'поттер',
#   'упоминаться',
#   'он',
#   'день',
#   'рождение',
#   'рон',
#   'гермиона',
#   'нет'],
#  ['они',
#   'книга',
#   'почти',
#   'не',
#   'упоминаться',
#   'хотя',
#   'рон',
#   'гермиона',
#   'день',
#   'рождение',
#   'праздноваться',
#   'течение',
#   'учебный',
#   'год',
#   'март',
#   'сентябрь',
#   'думать',
#   'дело',
#   'тот',
#   'что',
#   'главный',
#   'герой',
#   'вс',
#   'таки',
#   'гарри',
#   'да',
#   'другой',
#   'праздник',
#   'иметь',
#   'смысл',
#   'описывать',
#   'только',
#   'если',
#   'они',
#   'двигать',
#   'сюжет',
#   'вперд',
#   'день',
#   'рождение',
#   'гарри',
#   'это',
#   'всегда',
#   'начать',
#   'новый',
#   'книга',
#   'причм',
#   'чаща',
#   'всего',
#   'этот',
#   'день',
#   'происходить',
#   'важный',
#   'событие',
#   'например',
#   'тот',
#   'что',
#   'он',
#   'волшебник',
#   'гарри',
#   'узнать',
#   'именно',
#   'день',
#   'рождение',
#   'тот',
#   'день',
#   'когда',
#   'он',
#   'исполниться',
#   'он',
#   'лишиться',
#   'защита',
#   'свой',
#   'матерь',
#   'кстати',
#   'джоана',
#   'роулинга',
#   'день',
#   'рождение',
#   'один',
#   'день',
#   'гарри',
#   'июль'],
#  ['возможно', 'ли', 'съесть', 'целовать', 'банка', 'корица'],
#  ['маловероятный',
#   'в',
#   'один',
#   'уточнить',
#   'размер',
#   'банка',
#   'жестяной',
#   'баночка',
#   'из',
#   'под',
#   'кофе',
#   'обычный',
#   'литровый',
#   'трхлитровый',
#   'это',
#   'ведь',
#   'абсолютно',
#   'разный',
#   'количество',
#   'продукт',
#   'на',
#   'дело',
#   'съесть',
#   'хотя',
#   'бы',
#   'три',
#   'четыре',
#   'чайный',
#   'ложка',
#   'уже',
#   'успех',
#   'тот',
#   'же',
#   'по',
#   'идея',
#   'корица',
#   'больший',
#   'количество',
#   'мочь',
#   'нанести',
#   'вред',
#   'здоровье',
#   'проверять',
#   'на',
#   'собственный',
#   'опыт',
#   'не',
#   'рекомендовать'],
#  ['рассказать',
#   'система',
#   'образование',
#   'австрииконкретный',
#   'вуз',
#   'трудно',
#   'ли',
#   'поступать',
#   'жёсткий',
#   'ли',
#   'требование'],
#  ['то',
#   'что',
#   'на',
#   'основание',
#   'обучение',
#   'государственный',
#   'или',
#   'частное',
#   'вуз',
#   'можно',
#   'получить',
#   'вид',
#   'на',
#   'жительство',
#   'это',
#   'факт',
#   'ещё',
#   'по',
#   'закон',
#   'можно',
#   'до',
#   'часы',
#   'неделя',
#   'работать',
#   'ещ',
#   'австрийский',
#   'диплом',
#   'цениться',
#   'в',
#   'всм',
#   'мир',
#   'позволять',
#   'работать',
#   'по',
#   'специальность',
#   'беспрепятственно',
#   'вс',
#   'это',
#   'несомненно',
#   'доказывать',
#   'ещ',
#   'раз',
#   'что',
#   'есть',
#   'смысл',
#   'отправляться',
#   'получать',
#   'образование',
#   'именно',
#   'австрия'],
#  ['да',
#   'наверняка',
#   'требование',
#   'высокий',
#   'как',
#   'люба',
#   'другой',
#   'европейский',
#   'страна',
#   'тем',
#   'более',
#   'оценивание',
#   'проходить',
#   'открыто',
#   'объективно',
#   'учтом',
#   'многий',
#   'комплексный',
#   'показатель'],
#  ['если', 'не', 'заводить', 'ребёнок', 'кто', 'подать', 'вода'],
#  ['ответить',
#   'немного',
#   'старое',
#   'анекдот',
#   'вот',
#   'ты',
#   'не',
#   'хотеть',
#   'заводить',
#   'ребёнок',
#   'кто',
#   'стакан',
#   'вода',
#   'ты',
#   'старость',
#   'принесть',
#   'слуга',
#   'принесть',
#   'вот',
#   'кто'],
#  ['кто',
#   'если',
#   'не',
#   'ребёнок',
#   'подать',
#   'вода',
#   'представить',
#   'что',
#   'вы',
#   'вырасти',
#   'закончить',
#   'школа',
#   'решать',
#   'поступать',
#   'хороший',
#   'вуз',
#   'другой',
#   'город',
#   'работать',
#   'за',
#   'хороший',
#   'зарплата',
#   'столица',
#   'но',
#   'тут',
#   'вы',
#   'хватать',
#   'за',
#   'ручка',
#   'родитель',
#   'говорятсынок',
#   'мы',
#   'ты',
#   'вырастить',
#   'чтобы',
#   'ты',
#   'мы',
#   'подносить',
#   'вода',
#   'вы',
#   'такой',
#   'понравиться',
#   'бы',
#   'родитель',
#   'не',
#   'иметь',
#   'право',
#   'пользоваться',
#   'ребнкома',
#   'как',
#   'вещь',
#   'вы',
#   'он',
#   'родить',
#   'вырастить',
#   'далёкий',
#   'он',
#   'уже',
#   'сам',
#   'смотреть',
#   'помогать',
#   'вы',
#   'или',
#   'заняться',
#   'себя',
#   'год',
#   'уж',
#   'точно',
#   'человек',
#   'уметь',
#   'ходить',
#   'на',
#   'кухня',
#   'за',
#   'водичка'],
#  ['возможно',
#   'робот',
#   'или',
#   'умный',
#   'дом',
#   'справиться',
#   'такой',
#   'задача',
#   'так',
#   'же',
#   'бывать',
#   'случай',
#   'когда',
#   'человек',
#   'старость',
#   'сохранять',
#   'подвижность',
#   'взять',
#   'стакан',
#   'вода',
#   'для',
#   'они',
#   'не',
#   'проблема'],
#  ['большинство',
#   'современный',
#   'мужчина',
#   'по',
#   'россия',
#   'не',
#   'доживать',
#   'до',
#   'возраст',
#   'когда',
#   'нужно',
#   'подавать',
#   'вода',
#   'инфаркт',
#   'инсульт',
#   'косить',
#   'мужик',
#   'под',
#   'год',
#   'женщина',
#   'статистика',
#   'гуманный',
#   'хотя',
#   'тоже',
#   'не',
#   'ласковый',
#   'но',
#   'даже',
#   'если',
#   'получиться',
#   'дотянуть',
#   'до',
#   'пенсия',
#   'есть',
#   'соцопека',
#   'тоже',
#   'помочь',
#   'водоснабжение',
#   'под',
#   'старость',
#   'год'],
#  ['каков', 'ходить', 'качалка', 'девушка'],
#  ['как',
#   'весь',
#   'человек',
#   'вы',
#   'приходить',
#   'выполнять',
#   'тренер',
#   'или',
#   'уже',
#   'без',
#   'он',
#   'определённый',
#   'упражнение',
#   'потом',
#   'уходить',
#   'когда',
#   'ходить',
#   'зал',
#   'я',
#   'очень',
#   'редко',
#   'бывать',
#   'что',
#   'кто',
#   'то',
#   'думать',
#   'что',
#   'пришлый',
#   'туда',
#   'познакомиться',
#   'он'],
#  ['думать',
#   'что',
#   'вполне',
#   'нормальный',
#   'недалеко',
#   'от',
#   'дом',
#   'есть',
#   'очень',
#   'старый',
#   'качалка',
#   'древние',
#   'мужской',
#   'тренажёр',
#   'фотография',
#   'качковы'],
#  ['начало',
#   'ходить',
#   'зал',
#   'год',
#   'назад',
#   'тогда',
#   'я',
#   'быть',
#   'как',
#   'то',
#   'неловко',
#   'неуютный',
#   'но',
#   'потом',
#   'втянуться',
#   'заниматься',
#   'тренер',
#   'преимущественно',
#   'по',
#   'утро',
#   'я',
#   'казалось',
#   'что',
#   'толща',
#   'весь',
#   'женщина',
#   'который',
#   'там',
#   'встречать',
#   'хыхых',
#   'теперь',
#   'самый',
#   'смешно',
#   'хотя',
#   'весить',
#   'тогда',
#   'килограмм',
#   'при',
#   'рост',
#   'сантиметр',
#   'за',
#   'год',
#   'сбросить',
#   'вес',
#   'до',
#   'питание',
#   'измениться',
#   'не',
#   'очень',
#   'значительно',
#   'не',
#   'стать',
#   'считать',
#   'калория',
#   'но',
#   'весь',
#   'же',
#   'теперь',
#   'обходиться',
#   'без',
#   'ночное',
#   'зажор',
#   'перестать',
#   'сутулиться',
#   'стать',
#   'более',
#   'выносливый',
#   'энергичный',
#   'из',
#   'за',
#   'тренировка',
#   'по',
#   'утро',
#   'стать',
#   'ранний',
#   'вставать',
#   'считать',
#   'что',
#   'стоимость',
#   'абонемент',
#   'зал',
#   'индивидуальный',
#   'тренировка',
#   'это',
#   'хороший',
#   'вложение',
#   'сам',
#   'себя'],
#  ['смысл', 'каков', 'нормальный', 'так', 'же', 'как', 'мужчина'],
#  ['как',
#   'ожидание',
#   'влиять',
#   'на',
#   'результат',
#   'почему',
#   'часто',
#   'успех',
#   'достигаться',
#   'когда',
#   'на',
#   'он',
#   'особо',
#   'не',
#   'рассчитывать'],
#  ['результат',
#   'эксперимент',
#   'находиться',
#   'прямая',
#   'зависимость',
#   'не',
#   'только',
#   'от',
#   'условие',
#   'эксперимент',
#   'но',
#   'от',
#   'ожидание',
#   'личность',
#   'экспериментатор',
#   'этот',
#   'постулат',
#   'который',
#   'физик',
#   'стать',
#   'очевидный',
#   'только',
#   'появление',
#   'квантовый',
#   'механика',
#   'проведение',
#   'щелевой',
#   'эксперимент',
#   'лирик',
#   'известный',
#   'давно'],
#  ['скорее',
#   'наоборот',
#   'есть',
#   'такой',
#   'понятие',
#   'как',
#   'эффект',
#   'самоисполняться',
#   'пророчество',
#   'когда',
#   'ожидание',
#   'положительно',
#   'влиять',
#   'на',
#   'результат',
#   'за',
#   'счт',
#   'человек',
#   'который',
#   'бессознательно',
#   'этот',
#   'результат',
#   'продвигать',
#   'такой',
#   'образ',
#   'даже',
#   'ложный',
#   'невозможный',
#   'результат',
#   'становиться',
#   'реальность'],
#  ['почему',
#   'очень',
#   'старый',
#   'информация',
#   'шутка',
#   'интернет',
#   'называть',
#   'баян',
#   'связать',
#   'ли',
#   'это',
#   'древнерусский',
#   'сказитель',
#   'боян'],
#  ['это',
#   'выражение',
#   'произойти',
#   'из',
#   'старое',
#   'анекдот',
#   'хоронить',
#   'тщу',
#   'порвать',
#   'два',
#   'баян',
#   'который',
#   'настолько',
#   'часто',
#   'публиковаться',
#   'пользователь',
#   'на',
#   'один',
#   'из',
#   'форум',
#   'что',
#   'стать',
#   'нарицательный',
#   'название',
#   'старый',
#   'заездить',
#   'шутка',
#   'это',
#   'значение',
#   'ушл',
#   'масса'],
#  ['не',
#   'следовать',
#   'путать',
#   'бородатый',
#   'анекдот',
#   'баян',
#   'классика',
#   'баян',
#   'как',
#   'мы',
#   'выяснить',
#   'это',
#   'расхожий',
#   'анекдот',
#   'стать',
#   'слишком',
#   'расхожий',
#   'когда',
#   'весь',
#   'слушатель',
#   'слышать',
#   'он',
#   'уже',
#   'не',
#   'по',
#   'один',
#   'раз',
#   'мем',
#   'только',
#   'что',
#   'пройти',
#   'пик',
#   'свой',
#   'медийный',
#   'активность',
#   'пойти',
#   'на',
#   'убыль',
#   'новость',
#   'рука',
#   'слоупока',
#   'классика',
#   'же',
#   'возможно',
#   'когда',
#   'то',
#   'быть',
#   'баян',
#   'но',
#   'уже',
#   'выйти',
#   'из',
#   'жанр',
#   'анекдот',
#   'не',
#   'претендовать',
#   'на',
#   'принадлежность',
#   'таковой',
#   'теперь',
#   'это',
#   'крылатый',
#   'выражение',
#   'распространнный',
#   'ответ',
#   'на',
#   'типовой',
#   'ситуация',
#   'фразеологизм',
#   'что',
#   'угодный',
#   'только',
#   'не',
#   'анекдот',
#   'использоваться',
#   'по',
#   'место',
#   'по',
#   'назначение',
#   'сам',
#   'анекдот',
#   'считаться',
#   'классика',
#   'ознакомление',
#   'он',
#   'происходить',
#   'глубокий',
#   'детство',
#   'навсегда',
#   'только',
#   'альтернативный',
#   'одарнный',
#   'придт',
#   'голова',
#   'рассказывать',
#   'он',
#   'качество',
#   'анекдот',
#   'только',
#   'имя',
#   'же',
#   'мочь',
#   'прийти',
#   'голова',
#   'назвать',
#   'уместный',
#   'упоминание',
#   'классика',
#   'баян',
#   'ну',
#   'наконец',
#   'бородатый',
#   'анекдот',
#   'совсем',
#   'третье',
#   'явление',
#   'если',
#   'он',
#   'быть',
#   'хороший',
#   'годный',
#   'он',
#   'успеть',
#   'хорошо',
#   'забыть',
#   'он',
#   'очередной',
#   'раз',
#   'всплывать',
#   'веселить',
#   'нубова',
#   'он',
#   'ещ',
#   'не',
#   'знакомый',
#   'иногда',
#   'мочь',
#   'даже',
#   'повторно',
#   'побывать',
#   'баян',
#   'если',
#   'нубова',
#   'быть',
#   'много',
#   'анекдот',
#   'уж',
#   'слишком',
#   'эпик',
#   'вино',
#   'вот',
#   'такой',
#   'вот',
#   'профильный',
#   'для',
#   'уютненький',
#   'семантический',
#   'мемологический',
#   'тонкость',
#   'который',
#   'процент',
#   'употреблять',
#   'слово',
#   'баян',
#   'радикально',
#   'по'],
#  ['fido',
#   'ещ',
#   'до',
#   'баян',
#   'быть',
#   'курочка',
#   'тот',
#   'же',
#   'значение',
#   'анекдот',
#   'снести',
#   'курочка',
#   'яичко',
#   'дед',
#   'начисто',
#   'быть',
#   'заездить',
#   'донельзя',
#   'за',
#   'он',
#   'уже',
#   'наказывать',
#   'баян',
#   'появиться',
#   'когда',
#   'уже',
#   'интернет',
#   'быть',
#   'распространна',
#   'поэтому',
#   'сменить',
#   'курочка'],
#  ['собственно',
#   'баян',
#   'быть',
#   'самый',
#   'натуральный',
#   'форседой',
#   'мть',
#   'ещё',
#   'тот',
#   'время',
#   'когда',
#   'мем',
#   'не',
#   'быть',
#   'конец',
#   'на',
#   'легендарный',
#   'anekdot',
#   'ru',
#   'какой',
#   'то',
#   'умник',
#   'регулярно',
#   'постить',
#   'свежий',
#   'анекдот',
#   'история',
#   'про',
#   'тёща',
#   'баян',
#   'прижиться'],
#  ['одновременно',
#   'баян',
#   'появиться',
#   'канада',
#   'смешной',
#   'рассказ',
#   'снег',
#   'канада',
#   'который',
#   'быть',
#   'опубликовать',
#   'на',
#   'какой',
#   'то',
#   'паблик',
#   'раз',
#   'пятнадцать',
#   'течение',
#   'сутки',
#   'канада',
#   'один',
#   'время',
#   'так',
#   'же',
#   'как',
#   'баян',
#   'использоваться',
#   'тот',
#   'смысл',
#   'что',
#   'бородатый',
#   'анекдот',
#   'но',
#   'потом',
#   'про',
#   'канада',
#   'забыть',
#   'баян',
#   'прижиться'],
#  ['вопрос', 'боян', 'ресурс', 'lurkmore', 'to', 'статья', 'баян', 'сообщать'],
#  ['это',
#   'выражение',
#   'пошло',
#   'один',
#   'очень',
#   'старое',
#   'сайт',
#   'русский',
#   'анекдот',
#   'где',
#   'самый',
#   'популярный',
#   'анекдот',
#   'выбрать',
#   'хоронить',
#   'тщу',
#   'порвать',
#   'баян',
#   'очевидно',
#   'это',
#   'очень',
#   'страринный',
#   'анекдот'],
#  ['помнится',
#   'когда',
#   'я',
#   'задать',
#   'такой',
#   'вопрос',
#   'припомнить',
#   'древнерусский',
#   'песнопевец',
#   'баян',
#   'коллега',
#   'гомера',
#   'который',
#   'ходить',
#   'по',
#   'княжеский',
#   'корпоратив',
#   'развлекать',
#   'публика',
#   'байка',
#   'дескать',
#   'намёк',
#   'на',
#   'древность',
#   'аниматор',
#   'однобразность',
#   'он',
#   'репертуар'],
#  ['не',
#   'знать',
#   'правильно',
#   'это',
#   'или',
#   'нет',
#   'но',
#   'всегда',
#   'думать',
#   'что',
#   'это',
#   'пришлый',
#   'из',
#   'домино',
#   'не',
#   'так',
#   'давно',
#   'безынтернетный',
#   'ламповый',
#   'время',
#   'этот',
#   'игра',
#   'очень',
#   'активно',
#   'ходить',
#   'народ'],
#  ['слышать',
#   'такой',
#   'версия',
#   'что',
#   'пошло',
#   'это',
#   'выражение',
#   'от',
#   'имя',
#   'человек',
#   'боян',
#   'или',
#   'баян',
#   'два',
#   'этот',
#   'форма',
#   'исстари',
#   'употребляться',
#   'безразличный',
#   'один',
#   'то',
#   'же',
#   'лицо',
#   'называться',
#   'то',
#   'боян',
#   'то',
#   'баян',
#   'древнерусский',
#   'певец',
#   'сказитель',
#   'песнотворец',
#   'персонаж',
#   'слово',
#   'полка',
#   'игорев',
#   'боян',
#   'быть',
#   'автор',
#   'исполнитель',
#   'свой',
#   'песня',
#   'аккомпанировать',
#   'себя',
#   'на',
#   'струнный',
#   'инструмент',
#   'вроде',
#   'гусель',
#   'согласно',
#   'наиболее',
#   'распространнный',
#   'современный',
#   'наука',
#   'точка',
#   'зрение',
#   'боян',
#   'исторический',
#   'лицо',
#   'придворный',
#   'певец',
#   'ряд',
#   'русский',
#   'князь',
#   'xi',
#   'век',
#   'автор',
#   'слово',
#   'называть',
#   'трх',
#   'князь',
#   'который',
#   'воспевать',
#   'боян',
#   'брат',
#   'соперник',
#   'мстислав',
#   'владимир',
#   'храбрый',
#   'ярослав',
#   'мудрый',
#   'также',
#   'внук',
#   'два',
#   'из',
#   'они',
#   'роман',
#   'святосла',
#   'один',
#   'князь',
#   'который',
#   'боян',
#   'порицать',
#   'это',
#   'всеслав',
#   'полоцкий',
#   'так',
#   'вот',
#   'ходить',
#   'этот',
#   'баян',
#   'по',
#   'русь',
#   'напевать',
#   'один',
#   'тот',
#   'же',
#   'песенка',
#   'из',
#   'день',
#   'день',
#   'песнь',
#   'этот',
#   'по',
#   'русь',
#   'распространяться',
#   'быстрый',
#   'чем',
#   'он',
#   'сам',
#   'они',
#   'распространять',
#   'так',
#   'что',
#   'многие',
#   'уже',
#   'это',
#   'слышать',
#   'ещё',
#   'баян',
#   'быть',
#   'длинный',
#   'борода',
#   'так',
#   'что',
#   'вполне',
#   'можно',
#   'отнести',
#   'это',
#   'же',
#   'человек',
#   'фраза',
#   'бородатый',
#   'как',
#   'баян'],
#  ['по',
#   'один',
#   'из',
#   'теория',
#   'авторство',
#   'лежать',
#   'за',
#   'сказитель',
#   'тот',
#   'время',
#   'боян',
#   'именно',
#   'через',
#   'дробный',
#   'нм',
#   'можно',
#   'узнать',
#   'при',
#   'гуглении',
#   'слово'],
#  ['не', 'увидеть', 'тут', 'правильный', 'ответ'],
#  ['почему',
#   'некоторый',
#   'человек',
#   'не',
#   'любить',
#   'есть',
#   'корочка',
#   'от',
#   'пицца'],
#  ['как',
#   'человек',
#   'который',
#   'не',
#   'любить',
#   'есть',
#   'корочка',
#   'от',
#   'пицца',
#   'официально',
#   'заявлять',
#   'что',
#   'это',
#   'невкусно',
#   'сам',
#   'пицца',
#   'такой',
#   'весь',
#   'из',
#   'себя',
#   'многогранный',
#   'сыр',
#   'соус',
#   'мясо',
#   'весь',
#   'дело',
#   'корочка',
#   'что',
#   'корочка',
#   'скучно',
#   'постно',
#   'хотеться',
#   'ли',
#   'есть',
#   'простой',
#   'тесто'],
#  ['тоже',
#   'ответить',
#   'как',
#   'представитель',
#   'мы',
#   'просто',
#   'зажраться',
#   'после',
#   'тот',
#   'как',
#   'отработать',
#   'год',
#   'пекарня',
#   'где',
#   'вс',
#   'это',
#   'добро',
#   'есть',
#   'пачка',
#   'каждый',
#   'день',
#   'ещ',
#   'год',
#   'обкусывать',
#   'пицца',
#   'только',
#   'самый',
#   'вкусный',
#   'остальной',
#   'выкидывать',
#   'только',
#   'сейчас',
#   'начало',
#   'замечать',
#   'что',
#   'снова',
#   'есть',
#   'пицца',
#   'корочка',
#   'находить',
#   'они',
#   'вкусный'],
#  ['ещ',
#   'один',
#   'очень',
#   'весомый',
#   'причина',
#   'не',
#   'кушать',
#   'корочка',
#   'от',
#   'пицца',
#   'лишний',
#   'углевод',
#   'не',
#   'приносить',
#   'абсолютно',
#   'никакой',
#   'удовольствие',
#   'они',
#   'хороший',
#   'заменить',
#   'дополнительный',
#   'кусочек',
#   'пицца',
#   'нежели',
#   'безвкусный',
#   'корка'],
#  ['что', 'самый', 'важный', 'роман', 'юрий', 'мамлеева', 'шатун'],
#  ['важный',
#   'тот',
#   'что',
#   'вс',
#   'патологический',
#   'маниакальный',
#   'мамлеева',
#   'неразрывно',
#   'связать',
#   'трансцендентный',
#   'какой',
#   'то',
#   'невидимый',
#   'пропитывать',
#   'жизнь',
#   'абсолют',
#   'относительно',
#   'который',
#   'весь',
#   'остальной',
#   'реальность',
#   'по',
#   'большой',
#   'счтить',
#   'ненастоящий',
#   'ещ',
#   'важный',
#   'что',
#   'никак',
#   'кроме',
#   'как',
#   'через',
#   'это',
#   'патологический',
#   'маниакальный',
#   'герой',
#   'шатун',
#   'это',
#   'абсолют',
#   'соприкоснуться',
#   'не',
#   'мочь'],
#  ['возможно',
#   'ли',
#   'что',
#   'человечество',
#   'будущее',
#   'не',
#   'быть',
#   'использовать',
#   'достижение',
#   'генный',
#   'инженерия',
#   'кибернетика',
#   'полный',
#   'сила',
#   'ради',
#   'сохранение',
#   'человечность'],
#  ['правильно', 'ли', 'поставить', 'вопрос'],
#  ['какой', 'род', 'слово', 'карри'],
#  ['карри',
#   'специя',
#   'верный',
#   'смесь',
#   'специя',
#   'на',
#   'основа',
#   'корень',
#   'куркума',
#   'специя',
#   'смесь',
#   'куркума',
#   'женский',
#   'род',
#   'корень',
#   'куркума',
#   'мужской',
#   'такой',
#   'образ',
#   'польза',
#   'женский',
#   'род'],
#  ['какой',
#   'пример',
#   'действие',
#   'право',
#   'пространство',
#   'вы',
#   'мочь',
#   'привести'],
#  ['вопрос',
#   'не',
#   'корректный',
#   'но',
#   'смысл',
#   'он',
#   'более',
#   'менее',
#   'понятный',
#   'на',
#   'территория',
#   'рф',
#   'пространство',
#   'страна',
#   'закон',
#   'везде',
#   'действовать',
#   'одинаково',
#   'решение',
#   'суд',
#   'постановить',
#   'на',
#   'чукотка',
#   'обязательно',
#   'исполнение',
#   'дагестан'],
#  ['почему',
#   'сначала',
#   'класть',
#   'асфальт',
#   'потом',
#   'менять',
#   'под',
#   'он',
#   'труба'],
#  ['к',
#   'весь',
#   'ответ',
#   'добавить',
#   'ещё',
#   'ответ',
#   'свой',
#   'отец',
#   'строитель'],
#  ['отписаться',
#   'выше',
#   'добавить',
#   'свой',
#   'лепта',
#   'труба',
#   'как',
#   'асфальт',
#   'менять',
#   'когда',
#   'тот',
#   'выходить',
#   'из',
#   'строй',
#   'целовать',
#   'труба',
#   'никто',
#   'менять',
#   'не',
#   'быть',
#   'при',
#   'это',
#   'если',
#   'асфальт',
#   'испортиться',
#   'ранний',
#   'он',
#   'ранний',
#   'положить'],
#  ['добавление',
#   'предыдущий',
#   'ответ',
#   'про',
#   'распиздяйство',
#   'добавить',
#   'ещё',
#   'бюрократический',
#   'проволочка',
#   'как',
#   'правило',
#   'весь',
#   'этот',
#   'работа',
#   'делаться',
#   'по',
#   'тендер',
#   'который',
#   'подготовливаться',
#   'заранее',
#   'за',
#   'долгий',
#   'время',
#   'до',
#   'самый',
#   'непосредственный',
#   'исполнение',
#   'но',
#   'дорога',
#   'строить',
#   'ремонтировать',
#   'один',
#   'труба',
#   'другой',
#   'один',
#   'один',
#   'тендер',
#   'срок',
#   'план',
#   'другой',
#   'свой',
#   'этот',
#   'два',
#   'организация',
#   'никакой',
#   'образ',
#   'не',
#   'согласоваться',
#   'друг',
#   'друг',
#   'дорога',
#   'положить',
#   'жкх',
#   'свой',
#   'тендер',
#   'гореть',
#   'срок',
#   'определённый',
#   'вот',
#   'приходиться',
#   'по',
#   'чистый',
#   'снова',
#   'весь',
#   'разбирать'],
#  ['распиздяйство',
#   'один',
#   'единственный',
#   'девиз',
#   'россия',
#   'сначала',
#   'решать',
#   'поменять',
#   'где',
#   'то',
#   'асфальт',
#   'по',
#   'просьба',
#   'трудящийся',
#   'который',
#   'уже',
#   'пять',
#   'год',
#   'просить',
#   'перед',
#   'это',
#   'естественно',
#   'никто',
#   'заниматься',
#   'коммуникация',
#   'ряд',
#   'не',
#   'уведомить',
#   'тут',
#   'например',
#   'водоканал',
#   'видеть',
#   'что',
#   'на',
#   'такой',
#   'то',
#   'улица',
#   'менять',
#   'дорога',
#   'тоже',
#   'вспоминать',
#   'что',
#   'неплохо',
#   'бы',
#   'поменять',
#   'заодно',
#   'там',
#   'часть',
#   'трубопровод',
#   'но',
#   'пока',
#   'водоконать',
#   'тормозить',
#   'асфальт',
#   'уже',
#   'положить',
#   'чтобы',
#   'поменять',
#   'труба',
#   'он',
#   'надо',
#   'вскрывать',
#   'или',
#   'возможно',
#   'такой',
#   'когда',
#   'при',
#   'замена',
#   'асфальт',
#   'повреждаться',
#   'сам',
#   'труба',
#   'съм',
#   'старое',
#   'асфальт',
#   'стресс',
#   'для',
#   'весь',
#   'коммуникация',
#   'тряска',
#   'давление',
#   'сам',
#   'труба',
#   'зачастую',
#   'старое',
#   'так',
#   'на',
#   'ладан',
#   'дышать',
#   'после',
#   'вибрация',
#   'бульдозерный',
#   'отбойник',
#   'начинать',
#   'давать',
#   'течь'],
#  ['есть',
#   'ли',
#   'россия',
#   'действительно',
#   'независимый',
#   'объективный',
#   'сми'],
#  ['тут',
#   'надо',
#   'очень',
#   'чётко',
#   'уточнять',
#   'что',
#   'пониматься',
#   'под',
#   'независимость',
#   'объективность'],
#  ['можно', 'ли', 'приходить', 'церковь', 'проститутка'],
#  ['почему',
#   'нет',
#   'если',
#   'блуд',
#   'это',
#   'грех',
#   'то',
#   'если',
#   'церковь',
#   'ходить',
#   'тот',
#   'кто',
#   'грешить',
#   'значит',
#   'проститутка',
#   'можно'],
#  ['можно',
#   'но',
#   'хороший',
#   'анонимно',
#   'ибо',
#   'многие',
#   'верующий',
#   'этот',
#   'страна',
#   'не',
#   'особо',
#   'вникать',
#   'первоисточник',
#   'сантиметр',
#   'один',
#   'ответ',
#   'блудница',
#   'иисус',
#   'простить',
#   'один'],
#  ['наверное',
#   'можно',
#   'главный',
#   'чтобы',
#   'она',
#   'пришлый',
#   'покрыть',
#   'голова',
#   'платок',
#   'юбка',
#   'до',
#   'пята',
#   'без',
#   'открытый',
#   'плечо',
#   'также',
#   'ещ',
#   'приветствоваться',
#   'крест',
#   'на',
#   'шея'],
#  ['что',
#   'делать',
#   'если',
#   'не',
#   'мочь',
#   'сконцентрироваться',
#   'при',
#   'чтение',
#   'уже',
#   'достаточно',
#   'долгий',
#   'время',
#   'информация',
#   'совсем',
#   'не',
#   'ложиться',
#   'голова'],
#  ['самый',
#   'быть',
#   'такой',
#   'же',
#   'проблема',
#   'не',
#   'мочь',
#   'сконцентрироваться',
#   'не',
#   'только',
#   'при',
#   'чтение',
#   'но',
#   'на',
#   'другой',
#   'важный',
#   'дело',
#   'пока',
#   'не',
#   'понять',
#   'чм',
#   'же',
#   'крыться',
#   'причина',
#   'причина',
#   'плохой',
#   'концентрация',
#   'внимание',
#   'достаточно',
#   'много',
#   'сейчас',
#   'мы',
#   'рассмотреть',
#   'основной',
#   'фактор',
#   'мешать',
#   'мы',
#   'сконцентрироваться',
#   'постараться',
#   'они',
#   'разобраться'],
#  ['как',
#   'всегда',
#   'говорить',
#   'из',
#   'личный',
#   'опыт',
#   'который',
#   'мочь',
#   'быть',
#   'вы',
#   'абсолютно',
#   'не',
#   'тема',
#   'можно',
#   'читать',
#   'условно',
#   'говорить',
#   'упор',
#   'на',
#   'присвоение',
#   'можно',
#   'упор',
#   'на',
#   'бытие',
#   'здесь',
#   'нужно',
#   'разобраться',
#   'мотив',
#   'например',
#   'вы',
#   'выбрать',
#   'какой',
#   'нибыть',
#   'книга',
#   'почему',
#   'вы',
#   'выбрать',
#   'именно',
#   'интересно',
#   'ли',
#   'вы',
#   'читать',
#   'замечать',
#   'за',
#   'себя',
#   'что',
#   'иногда',
#   'читать',
#   'то',
#   'что',
#   'читать',
#   'весь',
#   'хотя',
#   'я',
#   'совершенно',
#   'неинтересно',
#   'внимание',
#   'я',
#   'непроизвольно',
#   'соскальзывать',
#   'с',
#   'страница',
#   'даже',
#   'иногда',
#   'пропускать',
#   'целое',
#   'абзац',
#   'текст',
#   'чтобы',
#   'быстрый',
#   'добраться',
#   'до',
#   'конец',
#   'книга',
#   'что',
#   'конец',
#   'книга',
#   'конец',
#   'книга',
#   'мочь',
#   'написать',
#   'ещ',
#   'один',
#   'строчка',
#   'воображать',
#   'тетрадочка',
#   'надпись',
#   'причина',
#   'почему',
#   'молодец',
#   'на',
#   'обложка',
#   'это',
#   'вот',
#   'чистый',
#   'присвоение',
#   'здесь',
#   'вообще',
#   'неважно',
#   'например',
#   'содержание',
#   'книга',
#   'ну',
#   'то',
#   'есть',
#   'оно',
#   'важный',
#   'конечно',
#   'но',
#   'сам',
#   'по',
#   'себя',
#   'не',
#   'интересовать',
#   'интересовать',
#   'только',
#   'как',
#   'информация',
#   'который',
#   'мочь',
#   'выдать',
#   'друг',
#   'чтобы',
#   'показаться',
#   'умный',
#   'чувак',
#   'тема',
#   'потом',
#   'вс',
#   'забываться',
#   'разумеется',
#   'если',
#   'часто',
#   'так',
#   'читать',
#   'то',
#   'можно',
#   'разучиться',
#   'читать',
#   'по',
#   'другой',
#   'тогда',
#   'даже',
#   'книга',
#   'который',
#   'вы',
#   'понравиться',
#   'бы',
#   'прожить',
#   'вы',
#   'смочь',
#   'только',
#   'присвоить',
#   'есть',
#   'другой',
#   'вариант',
#   'проживать',
#   'каждый',
#   'книга',
#   'давать',
#   'она',
#   'возможность',
#   'резонировать',
#   'чем',
#   'то',
#   'глубина',
#   'вы',
#   'для',
#   'это',
#   'нужно',
#   'понять',
#   'что',
#   'читать',
#   'ничто',
#   'не',
#   'более',
#   'почтный',
#   'чем',
#   'не',
#   'читать',
#   'чтение',
#   'увлекательно',
#   'ценный',
#   'сам',
#   'по',
#   'себя',
#   'без',
#   'подключение',
#   'гордыня',
#   'однако',
#   'мир',
#   'помимо',
#   'книга',
#   'есть',
#   'ещ',
#   'куча',
#   'всего',
#   'увлекательный',
#   'ценный',
#   'если',
#   'вы',
#   'не',
#   'захватывать',
#   'чтение',
#   'отложить',
#   'он',
#   'вс',
#   'равно',
#   'вс',
#   'забываться',
#   'же',
#   'наверняка',
#   'если',
#   'избавиться',
#   'от',
#   'гнт',
#   'обязаловка',
#   'который',
#   'навязывать',
#   'мы',
#   'школа',
#   'который',
#   'прививать',
#   'либо',
#   'стойкий',
#   'отвращение',
#   'либо',
#   'чисто',
#   'присвоительский',
#   'потребительский',
#   'отношение',
#   'книга',
#   'то',
#   'через',
#   'некоторый',
#   'время',
#   'желание',
#   'читать',
#   'придт',
#   'сам',
#   'есть',
#   'ещ',
#   'вариант',
#   'когда',
#   'нужно',
#   'читать',
#   'книга',
#   'чтобы',
#   'овладеть',
#   'какой',
#   'то',
#   'профессиональный',
#   'знание',
#   'сам',
#   'знание',
#   'при',
#   'это',
#   'ценный',
#   'увлекательный',
#   'для',
#   'вы',
#   'но',
#   'сложный',
#   'форма',
#   'подача',
#   'мочь',
#   'быть',
#   'не',
#   'самый',
#   'удачный',
#   'такой',
#   'случай',
#   'нужно',
#   'подключать',
#   'послепроизвольный',
#   'внимание',
#   'сначала',
#   'нужно',
#   'затратить',
#   'какой',
#   'то',
#   'усилие',
#   'чтобы',
#   'сконцентрироваться',
#   'направить',
#   'сво',
#   'внимание',
#   'на',
#   'книга',
#   'потом',
#   'внимание',
#   'перестат',
#   'требовать',
#   'произвольный',
#   'усилие',
#   'вы',
#   'условно',
#   'говорить',
#   'входить',
#   'поток',
#   'который',
#   'мочь',
#   'долгий',
#   'время',
#   'пребывать',
#   'если',
#   'мотивация',
#   'прочтение',
#   'сильный',
#   'вс',
#   'так',
#   'быть',
#   'главный',
#   'тут',
#   'перетерпеть',
#   'фаза',
#   'произвольный',
#   'внимание',
#   'если',
#   'это',
#   'совсем',
#   'уж',
#   'мучительный',
#   'вс',
#   'надо',
#   'работать',
#   'мотивация',
#   'либо',
#   'прояснять',
#   'либо',
#   'понять',
#   'что',
#   'делать',
#   'хотеться',
#   'что',
#   'то',
#   'абсолютно',
#   'другой',
#   'дисклеймера',
#   'не',
#   'практиковать',
#   'психолог',
#   'так',
#   'что',
#   'это',
#   'личный',
#   'опыт',
#   'as',
#   'is',
#   'надргать',
#   'примерно',
#   'отовсюду',
#   'идея'],
#  ['совет', 'мочь', 'дать', 'банальный', 'но', 'они', 'работать'],
#  ['ранний',
#   'регулярно',
#   'сталкиваться',
#   'подобный',
#   'проблема',
#   'лично',
#   'я',
#   'весь',
#   'вина',
#   'оказаться',
#   'банальный',
#   'загруженность',
#   'после',
#   'очередной',
#   'день',
#   'работыучеба',
#   'голов',
#   'ещё',
#   'долго',
#   'быть',
#   'мысль',
#   'не',
#   'давать',
#   'сконцентрироваться',
#   'на',
#   'чем',
#   'то',
#   'совершенно',
#   'не',
#   'относиться',
#   'повседневность',
#   'пара',
#   'месяц',
#   'тренировка',
#   'по',
#   'контроль',
#   'эмоция',
#   'весь',
#   'прошлый'],
#  ['на',
#   'работа',
#   'я',
#   'приходиться',
#   'ежедневно',
#   'вычитывать',
#   'множество',
#   'скучный',
#   'кривоватый',
#   'сео',
#   'текст',
#   'концентрация',
#   'теряться',
#   'уже',
#   'строка',
#   'найти',
#   'такой',
#   'выход',
#   'работать',
#   'таймер',
#   'то',
#   'есть',
#   'завозить',
#   'таймер',
#   'на',
#   'минута',
#   'ставить',
#   'себя',
#   'условие',
#   'что',
#   'это',
#   'время',
#   'читать',
#   'текст',
#   'затем',
#   'отдыхать',
#   'затем',
#   'снова',
#   'завозить',
#   'таймер',
#   'постепенно',
#   'можно',
#   'увеличивать',
#   'временной',
#   'интервал',
#   'чтение',
#   'я',
#   'помогать'],
#  ['я',
#   'кажется',
#   'что',
#   'это',
#   'усталость',
#   'вот',
#   'читать',
#   'книга',
#   'основное',
#   'по',
#   'утро',
#   'пока',
#   'еда',
#   'на',
#   'работа',
#   'вот',
#   'вечером',
#   'на',
#   'книга',
#   'уже',
#   'не',
#   'хватать'],
#  ['преподаватель',
#   'информатика',
#   'университет',
#   'недавно',
#   'поведать',
#   'мы',
#   'студент',
#   'что',
#   'человек',
#   'век',
#   'не',
#   'всегда',
#   'мочь',
#   'сконцентрироваться',
#   'на',
#   'чтение',
#   'большой',
#   'текст',
#   'из',
#   'за',
#   'привычка',
#   'листать',
#   'лента',
#   'вконтакте',
#   'твиттер',
#   'прочий',
#   'социальный',
#   'сеть',
#   'где',
#   'большой',
#   'набор',
#   'буква',
#   'редкость',
#   'посему',
#   'крайне',
#   'советовать',
#   'хотя',
#   'бы',
#   'на',
#   'время',
#   'ограничить',
#   'данный',
#   'действие',
#   'если',
#   'оно',
#   'иметь',
#   'место',
#   'быть',
#   'включить',
#   'сила',
#   'воля',
#   'конечно',
#   'мотивировать',
#   'себя',
#   'всячески',
#   'это',
#   'ведь',
#   'нужно',
#   'один',
#   'очередь',
#   'вы',
#   'не',
#   'кома',
#   'либо',
#   'ещё',
#   'задуматься'],
#  ['часто',
#   'сталкиваться',
#   'подобный',
#   'проблема',
#   'рассказать',
#   'как',
#   'выходить',
#   'из',
#   'этот',
#   'ситуация'],
#  ['раз',
#   'уж',
#   'тут',
#   'весь',
#   'по',
#   'разный',
#   'весь',
#   'расписать',
#   'позволить',
#   'себя',
#   'добавить',
#   'вот',
#   'такой',
#   'забавный',
#   'видео',
#   'comwatchvqwiusmvnhzy'],
#  ['не',
#   'нужно',
#   'заставлять',
#   'себя',
#   'читать',
#   'насильно',
#   'если',
#   'не',
#   'получаться',
#   'понять',
#   'информация',
#   'возможно',
#   'вы',
#   'пробовать',
#   'читать',
#   'неудобный',
#   'условие',
#   'мочь',
#   'быть',
#   'вокруг',
#   'вы',
#   'много',
#   'человек',
#   'слишком',
#   'шумно',
#   'или',
#   'вы',
#   'делать',
#   'это',
#   'когда',
#   'физически',
#   'устать',
#   'или',
#   'вы',
#   'думать',
#   'чм',
#   'то',
#   'друг',
#   'поэтому',
#   'не',
#   'понимать',
#   'смысл',
#   'тот',
#   'что',
#   'читать',
#   'вариант',
#   'мочь',
#   'быть',
#   'масса',
#   'поэтому',
#   'для',
#   'начало',
#   'нужно',
#   'быть',
#   'отдохнуть',
#   'выспаться',
#   'не',
#   'голодный',
#   'иначе',
#   'про',
#   'еда',
#   'думать',
#   'быть',
#   'нужно',
#   'сделать',
#   'комфортный',
#   'обстановка',
#   'себя',
#   'выбирать',
#   'по',
#   'возможность',
#   'такой',
#   'место',
#   'для',
#   'чтение',
#   'где',
#   'комфортно',
#   'светло',
#   'тихо',
#   'малолюдный',
#   'если',
#   'же',
#   'такой',
#   'возможность',
#   'нет',
#   'вокруг',
#   'вы',
#   'шумно',
#   'много',
#   'человек',
#   'то',
#   'попытаться',
#   'сконцентрироваться',
#   'на',
#   'самый',
#   'информация',
#   'иногда',
#   'получаться',
#   'отключить',
#   'слух',
#   'не',
#   'слышать',
#   'посторонний',
#   'шум',
#   'если',
#   'глубоко',
#   'погружаться',
#   'текст',
#   'книга',
#   'или',
#   'учебник',
#   'главный',
#   'чтобы',
#   'вы',
#   'быть',
#   'интересно',
#   'это',
#   'читать',
#   'или',
#   'вы',
#   'точно',
#   'знаете',
#   'что',
#   'вы',
#   'этот',
#   'информация',
#   'нужный',
#   'например',
#   'на',
#   'егэ',
#   'или',
#   'на',
#   'другой',
#   'экзамен',
#   'человек',
#   'мочь',
#   'решать',
#   'что',
#   'то',
#   'присутствие',
#   'другой',
#   'человек',
#   'также',
#   'на',
#   'урок',
#   'или',
#   'лекция',
#   'студент',
#   'ведь',
#   'как',
#   'то',
#   'читать',
#   'запоминать',
#   'информация',
#   'даже',
#   'если',
#   'лектор',
#   'это',
#   'время',
#   'говорить',
#   'вслух',
#   'или',
#   'кто',
#   'то',
#   'читать',
#   'свой',
#   'реферат',
#   'офис',
#   'тоже',
#   'бывать',
#   'довольно',
#   'шумно',
#   'но',
#   'сотрудник',
#   'умудряться',
#   'работать',
#   'учить',
#   'информация',
#   'читать',
#   'документ',
#   'мочь',
#   'привести',
#   'ещ',
#   'такой',
#   'пример',
#   'как',
#   'контактный',
#   'центр',
#   'работать',
#   'оператор',
#   'мы',
#   'довольно',
#   'шумно',
#   'но',
#   'приходиться',
#   'разговаривать',
#   'абонент',
#   'учить',
#   'новое',
#   'тариф',
#   'вс',
#   'такой',
#   'делать',
#   'это',
#   'хотя',
#   'шум',
#   'разговор',
#   'мешать',
#   'быть',
#   'бы',
#   'желание',
#   'вообщий',
#   'ещ',
#   'для',
#   'улучшение',
#   'память',
#   'мочь',
#   'посоветовать',
#   'вы',
#   'высыпаться',
#   'бегать',
#   'по',
#   'утро',
#   'большой',
#   'гулять',
#   'на',
#   'свежий',
#   'воздух',
#   'есть',
#   'большой',
#   'фрукт',
#   'овощ',
#   'это',
#   'вс',
#   'влиять',
#   'можно',
#   'попить',
#   'витамин',
#   'ну',
#   'если',
#   'уж',
#   'совсем',
#   'проблема',
#   'память',
#   'то',
#   'врач',
#   'шутить',
#   'не',
#   'стоить',
#   'с',
#   'здоровье',
#   'ещ',
#   'говорят',
#   'головоломка',
#   'кроссворд',
#   'улучшать',
#   'память'],
#  ['аналогичный',
#   'ситуация',
#   'читать',
#   'быстрый',
#   'чем',
#   'воспринимать',
#   'информация',
#   'поэтому',
#   'через',
#   'некоторый',
#   'время',
#   'обнаруживать',
#   'что',
#   'мысль',
#   'уйти',
#   'другой',
#   'сторона',
#   'приходиться',
#   'возвращаться',
#   'выход',
#   'найти',
#   'аудиокнига'],
#  ['абстрагироваться',
#   'от',
#   'тот',
#   'мысль',
#   'который',
#   'лезть',
#   'голова',
#   'вместо',
#   'книжный',
#   'информация',
#   'если',
#   'сразу',
#   'на',
#   'место',
#   'отвлечься',
#   'не',
#   'получаться',
#   'заняться',
#   'другой',
#   'дело',
#   'сделать',
#   'уборка',
#   'посмотреть',
#   'фильм',
#   'позвонить',
#   'родной',
#   'узнать',
#   'как',
#   'они',
#   'дело',
#   'поздний',
#   'вернуться',
#   'чтение'],
#  ['несомненно',
#   'что',
#   'на',
#   'это',
#   'влиять',
#   'множество',
#   'как',
#   'внешний',
#   'так',
#   'внутренний',
#   'фактор',
#   'мой',
#   'ответ',
#   'быть',
#   'сугубо',
#   'субъективный',
#   'так',
#   'вот',
#   'я',
#   'отвлекать',
#   'посторонний',
#   'шум',
#   'телевизор',
#   'или',
#   'музыка',
#   'на',
#   'фон',
#   'шум',
#   'из',
#   'окно',
#   'от',
#   'сосед',
#   'или',
#   'домашний',
#   'бытовуха',
#   'стараться',
#   'читать',
#   'исключительно',
#   'тишина',
#   'или',
#   'максимум',
#   'под',
#   'расслаблять',
#   'chilloutambient'],
#  ['для', 'что', 'нужно', 'парить', 'нога', 'горчица', 'при', 'простуда'],
#  ['для',
#   'тот',
#   'что',
#   'бы',
#   'соблюсти',
#   'ритуал',
#   'ну',
#   'подобный',
#   'мера',
#   'позволять',
#   'не',
#   'сидеть',
#   'без',
#   'дело',
#   'делать',
#   'вид',
#   'что',
#   'ты',
#   'лечиться'],
#  ['тоже',
#   'не',
#   'понимать',
#   'ладный',
#   'грудь',
#   'или',
#   'спин',
#   'нога',
#   'вроде',
#   'не',
#   'относиться',
#   'дыхательный',
#   'система',
#   'горчица',
#   'раздражать',
#   'кожа',
#   'расширять',
#   'сосуд',
#   'местно',
#   'увеличивать',
#   'трансфузия',
#   'иммунокомпетентный',
#   'клетка',
#   'кровь',
#   'что',
#   'способствовать',
#   'выздоровление'],
#  ['если',
#   'вы',
#   'мочь',
#   'свой',
#   'жизнь',
#   'начать',
#   'заново',
#   'прожить',
#   'по',
#   'новый',
#   'какой',
#   'бы',
#   'она',
#   'быть',
#   'что',
#   'бы',
#   'вы',
#   'делать',
#   'что',
#   'не',
#   'делать',
#   'что',
#   'изменить'],
#  ['самый',
#   'большой',
#   'ошибка',
#   'свой',
#   'жизнь',
#   'считать',
#   'то',
#   'что',
#   'ранний',
#   'быть',
#   'подверженный',
#   'стереотип',
#   'тип',
#   'мужик',
#   'должный',
#   'так',
#   'далее',
#   'мой',
#   'жена',
#   'это',
#   'развеять',
#   'за',
#   'что',
#   'она',
#   'большой',
#   'спасибо',
#   'если',
#   'бы',
#   'мочь',
#   'вернуть',
#   'весь',
#   'назад',
#   'встретиться',
#   'сам',
#   'себя',
#   'бы',
#   'сказать',
#   'себя',
#   'просто',
#   'быть',
#   'себя',
#   'пофига',
#   'что',
#   'другой',
#   'подумать',
#   'ты',
#   'делать',
#   'свой',
#   'выбор',
#   'этот',
#   'жизнь'],
#  ['есть',
#   'ли',
#   'какой',
#   'то',
#   'определённый',
#   'зависимость',
#   'между',
#   'объём',
#   'сумма',
#   'площадь',
#   'весь',
#   'грань',
#   'пирамида',
#   'неправильный'],
#  ['какой',
#   'то',
#   'определнный',
#   'нет',
#   'потому',
#   'что',
#   'как',
#   'минимум',
#   'объм',
#   'площадь',
#   'боков',
#   'поверхность',
#   'разный',
#   'образ',
#   'быть',
#   'зависеть',
#   'от',
#   'высота',
#   'пирамида',
#   'то',
#   'есть',
#   'они',
#   'соотношение',
#   'можно',
#   'вывести',
#   'вот',
#   'зависимость',
#   'вряд',
#   'ли',
#   'даже',
#   'для',
#   'правильный',
#   'пирамида'],
#  ['какой',
#   'способ',
#   'можно',
#   'продвинуть',
#   'группа',
#   'вконтактесайт',
#   'студия',
#   'по',
#   'дизайн'],
#  ['artem', 'bulatov'],
#  ['почему',
#   'на',
#   'официальный',
#   'сервер',
#   'от',
#   'valve',
#   'игра',
#   'counter',
#   'strike',
#   'global',
#   'offensive',
#   'стоить',
#   'tickrate',
#   'не',
#   'ведь',
#   'стрельба',
#   'намного',
#   'простой',
#   'при'],
#  ['мочь',
#   'сказать',
#   'точно',
#   'что',
#   'тикрейт',
#   'не',
#   'быть',
#   'из',
#   'за',
#   'дороговизна',
#   'обновление',
#   'оборудование',
#   'да',
#   'для',
#   'valve',
#   'это',
#   'тоже',
#   'выйти',
#   'кругленький',
#   'сумма',
#   'они',
#   'приоритет',
#   'стоить',
#   'количество',
#   'сервер',
#   'разный',
#   'страна',
#   'не',
#   'они',
#   'качество',
#   'да',
#   'для',
#   'тикрейт',
#   'нужно',
#   'чтобы',
# ...
#   'тот',
#   'образоваться',
#   'пустота',
#   'я',
#   'реально',
#   'ничто',
#   'не',
#   'приносить',
#   'удовольствие',
#   'я',
#   'быть',
#   'жутко',
#   'страшно',
#   'одиноко',
#   'так',
#   'прожить',
#   'большой',
#   'полгода',
#   'быть',
#   'мысль',
#   'суицид',
#   'они',
#   'я',
#   'пугать',
#   'конец',
#   'конец',
#   'я',
#   'стать',
#   'настолько',
#   'тошный',
#   'от',
#   'мой',
#   'образ',
#   'жизнь',
#   'что',
#   'решить',
#   'пойти',
#   'психотерапевт',
#   'ещё',
#   'ходить',
#   'на',
#   'консультация',
#   'но',
#   'депрессивный',
#   'состояние',
#   'практически',
#   'полностью',
#   'прошлый',
#   'немного',
#   'принимать',
#   'антидепрессант',
#   'для',
#   'запуск',
#   'процесс',
#   'выздоровление'],
#  ['предполагать',
#   'что',
#   'шутить',
#   'мы',
#   'то',
#   'же',
#   'самый',
#   'время',
#   'предполагать',
#   'что',
#   'не',
#   'шутить',
#   'то',
#   'есть',
#   'предполагаться',
#   'что',
#   'шутить',
#   'не',
#   'шутить',
#   'одновременно',
#   'это',
#   'что',
#   'шутка'],
#  ['это',
#   'два',
#   'противоположный',
#   'гипотеза',
#   'как',
#   'монетка',
#   'мы',
#   'подбрасывать',
#   'монетка',
#   'один',
#   'наш',
#   'гипотеза',
#   'быть',
#   'то',
#   'что',
#   'она',
#   'упасть',
#   'орёл',
#   'два',
#   'что',
#   'решка',
#   'мы',
#   'ещё',
#   'мочь',
#   'предположить',
#   'что',
#   'монетка',
#   'самоуничтожиться',
#   'что',
#   'упасть',
#   'ребро',
#   'но',
#   'это',
#   'не',
#   'быть',
#   'важный',
#   'то',
#   'что',
#   'весь',
#   'этот',
#   'гипотеза',
#   'противоположный',
#   'одновременно',
#   'истинный',
#   'быть',
#   'не',
#   'мочь'],
#  ['кто',
#   'бы',
#   'вы',
#   'хотеть',
#   'видеть',
#   'герой',
#   'программа',
#   'русский',
#   'норма'],
#  ['очень',
#   'бы',
#   'хотеть',
#   'константин',
#   'северинов',
#   'один',
#   'из',
#   'самый',
#   'передовой',
#   'молекулярный',
#   'биолог',
#   'мир',
#   'который',
#   'работать',
#   'crisprcas',
#   'вообще',
#   'очень',
#   'крутой'],
#  ['на',
#   'данный',
#   'момент',
#   'я',
#   'кажется',
#   'самый',
#   'желанный',
#   'герой',
#   'мочь',
#   'бы',
#   'стать',
#   'павел',
#   'дуров',
#   'возможно',
#   'это',
#   'слишком',
#   'ожидать',
#   'ответ',
#   'но',
#   'пожалуй',
#   'он',
#   'самый',
#   'популярный',
#   'сми',
#   'русский',
#   'человек',
#   'жить',
#   'за',
#   'граница',
#   'создать',
#   'немало',
#   'крутой',
#   'вещий',
#   'да',
#   'потенциальный',
#   'создатель',
#   'самый',
#   'большой',
#   'криптовалюта',
#   'плюс',
#   'он',
#   'явно',
#   'можно',
#   'задать',
#   'много',
#   'интересный',
#   'вопрос'],
#  ['юрий',
#   'мильнер',
#   'крупный',
#   'бизнесмен',
#   'тот',
#   'же',
#   'меценат',
#   'основатель',
#   'крупный',
#   'премия',
#   'breakthrough',
#   'prize',
#   'физика',
#   'математика',
#   'единственный',
#   'россиянин',
#   'входящий',
#   'список',
#   'бизнес',
#   'ум',
#   'современность'],
#  ['не',
#   'знать',
#   'можно',
#   'ли',
#   'он',
#   'назвать',
#   'русский',
#   'так',
#   'как',
#   'большой',
#   'часть',
#   'жизнь',
#   'персонаж',
#   'провести',
#   'канада',
#   'но',
#   'как',
#   'бы',
#   'то',
#   'ни',
#   'быть',
#   'это',
#   'виталик',
#   'бутерин',
#   'сооснователь',
#   'два',
#   'самый',
#   'сильный',
#   'криптовалюта',
#   'ethereum'],
#  ['мария',
#   'бухонина',
#   'который',
#   'запустить',
#   'шоу',
#   'booze',
#   'traveler',
#   'продать',
#   'он',
#   'travel',
#   'channel',
#   'ещё',
#   'написать',
#   'книга',
#   'inspired',
#   'true',
#   'stories',
#   'behind',
#   'famous',
#   'art',
#   'literature',
#   'music',
#   'and',
#   'film',
#   'вообще',
#   'она',
#   'один',
#   'из',
#   'самый',
#   'остроумный',
#   'человек',
#   'кто',
#   'знать'],
#  ['олесь', 'рулина', 'twitter', 'comolesyarulin'],
#  ['определённо', 'сергей', 'брина', 'или', 'евгений', 'чичваркин'],
#  ['почему',
#   'украина',
#   'не',
#   'видно',
#   'борьба',
#   'с',
#   'смертность',
#   'от',
#   'дтп',
#   'пять',
#   'тысяча',
#   'человек',
#   'год',
#   'погибать',
#   'из',
#   'за',
#   'плохой',
#   'разметка',
#   'неэффективный',
#   'система',
#   'штраф',
#   'весь',
#   'плевать'],
#  ['сожаление',
#   'украина',
#   'до',
#   'сей',
#   'пора',
#   'много',
#   'проблема',
#   'превышать',
#   'указанный',
#   'на',
#   'порядок',
#   'это',
#   'здравоохранение',
#   'охрана',
#   'окружающий',
#   'среда',
#   'уровень',
#   'жизнь',
#   'весь',
#   'они',
#   'свый',
#   'нынешний',
#   'состояние',
#   'отрицательно',
#   'влиять',
#   'на',
#   'продолжительность',
#   'жизнь'],
#  ['последний',
#   'время',
#   'намечаться',
#   'улучшение',
#   'город',
#   'снизить',
#   'максимальный',
#   'скорость',
#   'до',
#   'кмч',
#   'как',
#   'помнить',
#   'увеличить',
#   'штраф',
#   'за',
#   'превышение',
#   'скорость'],
#  ['честь',
#   'что',
#   'трамп',
#   'поручить',
#   'провести',
#   'военный',
#   'парад',
#   'вашингтон'],
#  ['насколько',
#   'видеть',
#   'из',
#   'пресса',
#   'никакой',
#   'конкретный',
#   'повод',
#   'пока',
#   'нет',
#   'мочь',
#   'парад',
#   'создать'],
#  ['какой',
#   'волгоград',
#   'есть',
#   'футбольный',
#   'традиция',
#   'как',
#   'они',
#   'измениться',
#   'связь',
#   'чемпионат'],
#  ['волгоградский',
#   'команда',
#   'ротор',
#   'год',
#   'играть',
#   'высокий',
#   'лига',
#   'являться',
#   'серебряный',
#   'призром',
#   'чемпионат',
#   'россия',
#   'волгоград',
#   'проходить',
#   'матч',
#   'участие',
#   'команда',
#   'мировой',
#   'уровень',
#   'также',
#   'финальный',
#   'матч',
#   'чемпионат',
#   'страна',
#   'так',
#   'что',
#   'традиция',
#   'город',
#   'есть',
#   'мировой',
#   'чемпионат',
#   'придать',
#   'имя',
#   'дополнительный',
#   'стимул',
#   'развитие'],
#  ['возможно',
#   'ли',
#   'доказать',
#   'летний',
#   'ватник',
#   'что',
#   'путин',
#   'зло',
#   'телевизор',
#   'врать'],
#  ['возможно',
#   'но',
#   'сложно',
#   'уровень',
#   'дискуссия',
#   'наш',
#   'общество',
#   'находиться',
#   'на',
#   'очень',
#   'плохой',
#   'уровень',
#   'потому',
#   'что',
#   'переубедить',
#   'человек',
#   'трудоёмкий',
#   'ведь',
#   'доказывать',
#   'нужно',
#   'строгий',
#   'соблюдение',
#   'тезис',
#   'набор',
#   'аргумент',
#   'например',
#   'утверждение',
#   'что',
#   'конкретный',
#   'человек',
#   'чистый',
#   'зло',
#   'мочь',
#   'разбить',
#   'люба',
#   'так',
#   'как',
#   'уравнивать',
#   'категория',
#   'человек',
#   'не',
#   'представляться',
#   'логически',
#   'возможный',
#   'большой',
#   'шанс',
#   'вы',
#   'быть',
#   'если',
#   'вы',
#   'быть',
#   'говорить',
#   'что',
#   'человек',
#   'плохой',
#   'свой',
#   'профессия',
#   'он',
#   'деятельность',
#   'плохо',
#   'влиять',
#   'на',
#   'общество',
#   'дать',
#   'случай',
#   'оставаться',
#   'работа',
#   'факт',
#   'но',
#   'учесть',
#   'что',
#   'за',
#   'уровень',
#   'дискуссия',
#   'отвечать',
#   'оба',
#   'сторона'],
#  ['про',
#   'враньё',
#   'телевизор',
#   'можно',
#   'но',
#   'про',
#   'путин',
#   'нет',
#   'ибо',
#   'весь',
#   'человек',
#   'различный',
#   'жизненный',
#   'багаж',
#   'опыт',
#   'ценность',
#   'предпочтение'],
#  ['это',
#   'он',
#   'ватник',
#   'рассказать',
#   'киселть',
#   'на',
#   'следующий',
#   'день',
#   'после',
#   'тот',
#   'как',
#   'путин',
#   'прокатить',
#   'на',
#   'лафет',
#   'российский',
#   'традиция',
#   'каждый',
#   'новый',
#   'правитель',
#   'весь',
#   'косяк',
#   'проблема',
#   'страна',
#   'валита',
#   'на',
#   'предыдущий',
#   'правитель',
#   'на',
#   'следующий',
#   'день',
#   'после',
#   'смерть',
#   'путин',
#   'можно',
#   'включать',
#   'нтв',
#   'не',
#   'выключать',
#   'он',
#   'несколько',
#   'неделя',
#   'быть',
#   'много',
#   'интересный',
#   'про',
#   'путин',
#   'он',
#   'дочь',
#   'окружение',
#   'запастись',
#   'терпение',
#   'ещ',
#   'никто',
#   'не',
#   'удаться',
#   'жить',
#   'вечно'],
#  ['обязательно', 'нужно', 'доказывать'],
#  ['возможно', 'ли', 'доказать', 'летний', 'ватник', 'что', 'путин', 'зло'],
#  ['я',
#   'кажется',
#   'большинство',
#   'здравомыслящий',
#   'летний',
#   'россиянин',
#   'доказывать',
#   'ничто',
#   'не',
#   'нужно',
#   'они',
#   'нормальный',
#   'успешный',
#   'жизнь',
#   'карьер',
#   'целиком',
#   'порушить',
#   'ельцинско',
#   'путинский',
#   'шайка',
#   'многие',
#   'из',
#   'они',
#   'мочь',
#   'бы',
#   'стать',
#   'успешный',
#   'руководитель',
#   'высококлассный',
#   'специалист',
#   'но',
#   'почти',
#   'весь',
#   'промышленный',
#   'сельскохозяйственный',
#   'предприятие',
#   'где',
#   'они',
#   'быть',
#   'нужный',
#   'быть',
#   'успешно',
#   'похерить',
#   'весь',
#   'этот',
#   'путин',
#   'медведев',
#   'силуановое',
#   'кудрин',
#   'пр',
#   'пр',
#   'скорее',
#   'это',
#   'нужно',
#   'доказывать',
#   'современный',
#   'офисный',
#   'планктон'],
#  ['возможно', 'ли', 'доказать', 'летний', 'ватник', 'что', 'путин', 'зло'],
#  ['ватник',
#   'на',
#   'факт',
#   'не',
#   'реагировать',
#   'поддерживать',
#   'путин',
#   'исключительно',
#   'два',
#   'категория',
#   'идиот',
#   'тот',
#   'кома',
#   'выгодно',
#   'кто',
#   'воровать',
#   'тем',
#   'другой',
#   'факт',
#   'приводить',
#   'бесполезный'],
#  ['я',
#   'доказывать',
#   'не',
#   'надо',
#   'мы',
#   'поколение',
#   'битлз',
#   'хиппи',
#   'стивить',
#   'уандёр'],
#  ['путин',
#   'потерять',
#   'мо',
#   'доверие',
#   'после',
#   'тот',
#   'как',
#   'подписать',
#   'закон',
#   'яров',
#   'конкретно',
#   'один',
#   'вредный',
#   'решение',
#   'хранение',
#   'передаваемый',
#   'по',
#   'сеть',
#   'дать',
#   'весь',
#   'абонент',
#   'думать',
#   'что',
#   'можно',
#   'донести',
#   'такой',
#   'идея',
#   'даже',
#   'до',
#   'ватник',
#   'один',
#   'сторона',
#   'это',
#   'очень',
#   'дорого',
#   'тариф',
#   'на',
#   'связь',
#   'быть',
#   'растить',
#   'можно',
#   'привести',
#   'оценка',
#   'порядок',
#   'несколько',
#   'сотня',
#   'миллиард',
#   'рубль',
#   'другой',
#   'бестолковый',
#   'так',
#   'как',
#   'передаваемый',
#   'по',
#   'интернет',
#   'информация',
#   'чаща',
#   'всего',
#   'шифроваться',
#   'объм',
#   'очень',
#   'велик',
#   'телефонный',
#   'разговор',
#   'смска',
#   'ещ',
#   'есть',
#   'какой',
#   'то',
#   'смысл',
#   'хранить',
#   'но',
#   'обычный',
#   'сейчас',
#   'мегабит',
#   'интернет',
#   'это',
#   'примерно',
#   'тысяча',
#   'стандартный',
#   'телефонный',
#   'канал',
#   'gsm',
#   'на',
#   'кбитс',
#   'третье',
#   'общественность',
#   'быть',
#   'против',
#   'такой',
#   'решение',
#   'он',
#   'весь',
#   'равно',
#   'принять',
#   'значит',
#   'власть',
#   'плевать',
#   'на',
#   'мнение',
#   'человек',
#   'четвртый',
#   'неизвестно',
#   'куда',
#   'этот',
#   'дать',
#   'попасть',
#   'учитывать',
#   'слива',
#   'всякий',
#   'база',
#   'дать',
#   'россия',
#   'да',
#   'телефонный',
#   'разговор',
#   'нет',
#   'возможность',
#   'отслеживать',
#   'реальный',
#   'время',
#   'оборудование',
#   'ещ',
#   'не',
#   'настолько',
#   'совершенно',
#   'тем',
#   'более',
#   'общение',
#   'сейчас',
#   'переходить',
#   'интернет',
#   'шифрование',
#   'это',
#   'решение',
#   'иметь',
#   'явный',
#   'коррупционный',
#   'составлять',
#   'кто',
#   'быть',
#   'поставлять',
#   'оборудование',
#   'для',
#   'такой',
#   'хранение',
#   'наверняка',
#   'фирма',
#   'как',
#   'то',
#   'связанный',
#   'протолкнуть',
#   'такой',
#   'решение',
#   'депутат',
#   'на',
#   'это',
#   'пример',
#   'хорошо',
#   'видный',
#   'быть',
#   'лозунг',
#   'навальный',
#   'единый',
#   'россия',
#   'партия',
#   'жулик',
#   'вор',
#   'они',
#   'жульничать',
#   'когда',
#   'говорят',
#   'что',
#   'принять',
#   'этот',
#   'партия',
#   'закон',
#   'мочь',
#   'помочь',
#   'решить',
#   'проблема',
#   'терроризм',
#   'в',
#   'один',
#   'не',
#   'решить',
#   'никак',
#   'в',
#   'второе',
#   'терроризм',
#   'не',
#   'являться',
#   'такой',
#   'важный',
#   'проблема',
#   'на',
#   'дорога',
#   'или',
#   'от',
#   'рак',
#   'погибать',
#   'сотня',
#   'тысяча',
#   'раз',
#   'большой',
#   'человек',
#   'воровать',
#   'народ',
#   'платить',
#   'большой',
#   'но',
#   'не',
#   'получать',
#   'никакой',
#   'польза',
#   'значит',
#   'он',
#   'просто',
#   'украсть',
#   'деньга',
#   'путин',
#   'это',
#   'просто',
#   'неформальный',
#   'лидер',
#   'правящий',
#   'партия',
#   'партия',
#   'жулик',
#   'вор',
#   'стоить',
#   'ли',
#   'доверять',
#   'такой',
#   'политика',
#   'думать',
#   'что',
#   'нет'],
#  ['нет',
#   'ничто',
#   'простой',
#   'собрать',
#   'конкретный',
#   'факт',
#   'ничто',
#   'не',
#   'перевирать',
#   'не',
#   'передёргивать',
#   'доказать',
#   'не',
#   'способный',
#   'тогда',
#   'мочь',
#   'это',
#   'вы',
#   'что',
#   'то',
#   'не',
#   'так',
#   'не',
#   'путин',
#   'зло',
#   'подозревать',
#   'что',
#   'это',
#   'быть',
#   'лично',
#   'для',
#   'вы',
#   'путин',
#   'зло',
#   'но',
#   'лично',
#   'вы',
#   'не',
#   'способный',
#   'обосновать',
#   'это',
#   'никакой',
#   'внятный',
#   'претензия',
#   'кроме',
#   'путин',
#   'я',
#   'коммунизм',
#   'не',
#   'построить'],
#  ['интересно',
#   'поставить',
#   'вопрос',
#   'особенно',
#   'слово',
#   'ватник',
#   'сразу',
#   'пахнуть',
#   'незалежный',
#   'там',
#   'уровень',
#   'вменяемость',
#   'зашкаливать',
#   'имя',
#   'легко',
#   'доказать',
#   'что',
#   'россия',
#   'друг',
#   'путин',
#   'хороший',
#   'поэтому',
#   'ответ',
#   'находиться',
#   'самый',
#   'вопрос',
#   'если',
#   'присутствовать',
#   'слово',
#   'ватник',
#   'агрессор',
#   'быдло',
#   'то',
#   'ответ',
#   'на',
#   'данный',
#   'вопрос',
#   'автор',
#   'не',
#   'подразумеваться',
#   'потому',
#   'что',
#   'это',
#   'уже',
#   'переходить',
#   'ранг',
#   'пропаганда',
#   'также',
#   'можно',
#   'добавить',
#   'что',
#   'конструкция',
#   'это',
#   'вопрос',
#   'основать',
#   'на',
#   'мнимый',
#   'превосходство',
#   'задавать',
#   'над',
#   'летний',
#   'человек',
#   'он',
#   'ватник',
#   'нормальный',
#   'на',
#   'это',
#   'основать',
#   'национализм',
#   'фашизм',
#   'если',
#   'принять',
#   'что',
#   'весь',
#   'человек',
#   'разный',
#   'но',
#   'равный',
#   'то',
#   'этот',
#   'вопрос',
#   'не',
#   'иметь',
#   'смысл'],
#  ['совершенно',
#   'бесполезный',
#   'спорый',
#   'обычно',
#   'тот',
#   'кто',
#   'сейчас',
#   'называть',
#   'ватник',
#   'это',
#   'человек',
#   'большинство',
#   'свой',
#   'не',
#   'заблудший',
#   'или',
#   'не',
#   'знающий',
#   'некий',
#   'правда',
#   'который',
#   'имя',
#   'нужно',
#   'открыть',
#   'они',
#   'уверить',
#   'что',
#   'жизнь',
#   'так',
#   'устроить',
#   'как',
#   'животный',
#   'мир',
#   'по',
#   'другой',
#   'быть',
#   'не',
#   'мочь',
#   'что',
#   'сильный',
#   'убивать',
#   'слабый',
#   'коррупция',
#   'есть',
#   'везде',
#   'они',
#   'считать',
#   'что',
#   'это',
#   'нормальный',
#   'тот',
#   'кто',
#   'спорить',
#   'они',
#   'они',
#   'считать',
#   'наивный',
#   'простак',
#   'или',
#   'намеренно',
#   'желающий',
#   'развал',
#   'страна',
#   'считать',
#   'что',
#   'это',
#   'основное',
#   'неудачник',
#   'завистник',
#   'прочий',
#   'для',
#   'они',
#   'понятие',
#   'свобода',
#   'право',
#   'человек',
#   'демократия',
#   'это',
#   'что',
#   'то',
#   'тип',
#   'утопический',
#   'для',
#   'запудривание',
#   'мозги',
#   'слово',
#   'толерантность',
#   'так',
#   'вообще',
#   'ассоциироваться',
#   'только',
#   'лгбт',
#   'сообщество',
#   'так',
#   'что',
#   'спорить',
#   'они',
#   'ещё',
#   'опасный',
#   'мочь',
#   'обвинить',
#   'неверный',
#   'ориентация',
#   'ну',
#   'они',
#   'нафиг',
#   'по',
#   'суть',
#   'россия',
#   'пропагандироваться',
#   'фашизм',
#   'часто',
#   'спор',
#   'можно',
#   'услышать',
#   'аргумент',
#   'что',
#   'мир',
#   'действовать',
#   'закон',
#   'животное',
#   'мир',
#   'ну',
#   'пример',
#   'мы',
#   'захватить',
#   'крым',
#   'на',
#   'право',
#   'сильный',
#   'государство',
#   'но',
#   'иногда',
#   'бывать',
#   'что',
#   'промолчать',
#   'невозможно',
#   'тогда',
#   'нужный',
#   'простой',
#   'понятный',
#   'тугой',
#   'ум',
#   'пример',
#   'касаться',
#   'он',
#   'чтобы',
#   'он',
#   'зайти',
#   'тупик',
#   'начать',
#   'юлить',
#   'перевёртывать',
#   'этот',
#   'момент',
#   'он',
#   'начинать',
#   'понимать',
#   'но',
#   'ненадолго',
#   'следующий',
#   'раз',
#   'он',
#   'опять',
#   'быть',
#   'твердить',
#   'свой',
#   'голов',
#   'такой',
#   'человек',
#   'бардак',
#   'они',
#   'нет',
#   'логика',
#   'путать',
#   'причинный',
#   'следственный',
#   'связь'],
#  ['доказывать',
#   'надо',
#   'не',
#   'летний',
#   'ватник',
#   'который',
#   'как',
#   'раз',
#   'быть',
#   'участник',
#   'событие',
#   'год',
#   'летний',
#   'пепси',
#   'поклонник',
#   'который',
#   'массово',
#   'голосовать',
#   'за',
#   'путин'],
#  ['согласиться',
#   'некоторый',
#   'высказывание',
#   'выше',
#   'немного',
#   'дополнить',
#   'дело',
#   'тот',
#   'что',
#   'проблема',
#   'ватный',
#   'мышление',
#   'происходить',
#   'именно',
#   'из',
#   'абсолютный',
#   'доверие',
#   'государственный',
#   'сми',
#   'отсутствие',
#   'критический',
#   'восприятие',
#   'информация',
#   'заставлять',
#   'такой',
#   'человек',
#   'поверить',
#   'непогрешимость',
#   'дать',
#   'случай',
#   'путин',
#   'также',
#   'то',
#   'что',
#   'в',
#   'весь',
#   'проблема',
#   'рф',
#   'виноватый',
#   'исключительно',
#   'происки',
#   'заграничный',
#   'враг'],
#  ['про',
#   'телевизор',
#   'легко',
#   'достаточно',
#   'привести',
#   'конкретный',
#   'факт',
#   'враньё',
#   'про',
#   'путин',
#   'сложный',
#   'если',
#   'автор',
#   'вопрос',
#   'мыслить',
#   'категория',
#   'путин',
#   'зло',
#   'или',
#   'путин',
#   'добро',
#   'то',
#   'он',
#   'ещ',
#   'рано',
#   'рассуждать',
#   'политика',
#   'тем',
#   'более',
#   'кома',
#   'то',
#   'что',
#   'то',
#   'доказывать',
#   'сначала',
#   'надо',
#   'повзрослеть'],
#  ...]

# %%
word2vec_size=128

# %%
w2v = models.Word2Vec(corpus, min_count=1, size=word2vec_size, workers=10)

# %%
PAD_ix = token_to_id["_PAD_"]
UNK_ix = token_to_id['_UNK_']

def as_matrix(sequences, max_len=None):
    if isinstance(sequences[0], (str, bytes)):
        sequences = [text_to_tokens(s) for s in sequences]
        
    max_len = max_len or max(map(len,sequences))
    
    matrix = np.zeros((len(sequences), max_len), dtype='int32') + PAD_ix
    for i, seq in enumerate(sequences):
        row_ix = [token_to_id.get(word, UNK_ix) for word in seq[:max_len]]
        matrix[i, :len(row_ix)] = row_ix
    
    return matrix

# %%
w2v.wv.vocab
# Out:
# {'какой': <gensim.models.keyedvectors.Vocab at 0x7fa83549e9e8>,
#  'документальный': <gensim.models.keyedvectors.Vocab at 0x7fa841369588>,
#  'фильм': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d128>,
#  'вы': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3def0>,
#  'считать': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d780>,
#  'самый': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d3c8>,
#  'интересный': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d2e8>,
#  'качественный': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d4e0>,
#  'дом': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d6a0>,
#  'который': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d588>,
#  'многие': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d668>,
#  'слышать': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d8d0>,
#  'часть': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d208>,
#  'этот': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d160>,
#  'многий': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d240>,
#  'уже': <gensim.models.keyedvectors.Vocab at 0x7fa7fee3d2b0>,
#  'писать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7048>,
#  'да': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7080>,
#  'он': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a70b8>,
#  'запретить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a70f0>,
#  'красить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7128>,
#  'потому': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7160>,
#  'что': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7198>,
#  'люк': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a71d0>,
#  'бессон': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7208>,
#  'фотограф': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7240>,
#  'артюс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7278>,
#  'бертран': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a72b0>,
#  'мы': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a72e8>,
#  'мочь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7320>,
#  'увидеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7358>,
#  'свой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7390>,
#  'планет': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a73c8>,
#  'сидеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7400>,
#  'маленькая': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7438>,
#  'комнатушка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7470>,
#  'отделать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a74a8>,
#  'по': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a74e0>,
#  'европейск': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7518>,
#  'также': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7550>,
#  'сознание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7588>,
#  'заставить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a75c0>,
#  'задуматься': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a75f8>,
#  'же': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7630>,
#  'делать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7668>,
#  'собственный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a76a0>,
#  'ракурс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a76d8>,
#  'правдивость': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7710>,
#  'не': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7748>,
#  'менее': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7780>,
#  'прекрасный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a77b8>,
#  'занимательный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a77f0>,
#  'манхеттен': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7828>,
#  'manhatta': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7860>,
#  'сша': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7898>,
#  'чарльз': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a78d0>,
#  'шилера': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7908>,
#  'половина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7940>,
#  'страндт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7978>,
#  'зачем': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a79b0>,
#  'samsung': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a79e8>,
#  'htc': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7a20>,
#  'возвращать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7a58>,
#  'на': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7a90>,
#  'рынок': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7ac8>,
#  'смартфон': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7b00>,
#  'раскладушка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7b38>,
#  'нельзя': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7b70>,
#  'сказать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7ba8>,
#  'чтобы': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7be0>,
#  'они': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7c18>,
#  'то': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7c50>,
#  'такой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7c88>,
#  'популярный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7cc0>,
#  'азия': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7cf8>,
#  'ряд': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7d30>,
#  'страна': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7d68>,
#  'частность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7da0>,
#  'южный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7dd8>,
#  'корея': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7e10>,
#  'япония': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7e48>,
#  'только': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7e80>,
#  'быть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7eb8>,
#  'есть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7ef0>,
#  'новое': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7f28>,
#  'модель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7f60>,
#  'это': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7f98>,
#  'форма': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a7fd0>,
#  'фактор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4048>,
#  'выпускаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4080>,
#  'давно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a40b8>,
#  'ежегодно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a40f0>,
#  'высокий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4128>,
#  'цена': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4160>,
#  'неудивительный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4198>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a41d0>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4208>,
#  'всегда': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4240>,
#  'достаточно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4278>,
#  'дорогой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a42b0>,
#  'но': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a42e8>,
#  'при': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4320>,
#  'классно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4358>,
#  'если': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4390>,
#  'бы': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a43c8>,
#  'создать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4400>,
#  'сенсор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4438>,
#  'помнить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4470>,
#  'ранний': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a44a8>,
#  'весь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a44e0>,
#  'мечтать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4518>,
#  'завидовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4550>,
#  'тем': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4588>,
#  'кто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a45c0>,
#  'она': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a45f8>,
#  'мода': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4630>,
#  'айфон': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4668>,
#  'удовольствие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a46a0>,
#  'ходить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a46d8>,
#  'так': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4710>,
#  'пусть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4748>,
#  'усовершенствовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4780>,
#  'круто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a47b8>,
#  'когда': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a47f0>,
#  'лёгкий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4828>,
#  'похудеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4860>,
#  'зимой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4898>,
#  'или': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a48d0>,
#  'летом': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4908>,
#  'лёгкость': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4940>,
#  'похудение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4978>,
#  'зависеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a49b0>,
#  'от': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a49e8>,
#  'сугубо': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4a20>,
#  'личный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4a58>,
#  'особенность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4a90>,
#  'кома': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4ac8>,
#  'хотеться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4b00>,
#  'заедать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4b38>,
#  'зимний': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4b70>,
#  'хандра': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4ba8>,
#  'тёплый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4be0>,
#  'пончик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4c18>,
#  'какао': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4c50>,
#  'устоять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4c88>,
#  'перед': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4cc0>,
#  'перспектива': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4cf8>,
#  'поехать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4d30>,
#  'пляж': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4d68>,
#  'шашлык': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4da0>,
#  'пиво': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4dd8>,
#  'я': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4e10>,
#  'простой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4e48>,
#  'догонять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4e80>,
#  'ночной': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4eb8>,
#  'дожор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4ef0>,
#  'днём': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4f28>,
#  'кусок': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4f60>,
#  'горло': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4f98>,
#  'лезть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31a4fd0>,
#  'вечером': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa048>,
#  'холодок': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa080>,
#  'мгновенно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa0b8>,
#  'напихаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa0f0>,
#  'ништячка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa128>,
#  'разумеется': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa160>,
#  'намного': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa198>,
#  'терморегуляция': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa1d0>,
#  'фруктик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa208>,
#  'дело': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa240>,
#  'сделать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa278>,
#  'таки': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa2b0>,
#  'удаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa2e8>,
#  'разгар': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa320>,
#  'зима': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa358>,
#  'опыт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa390>,
#  'сбрасывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa3c8>,
#  'вес': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa400>,
#  'конечно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa438>,
#  'хочетсявидеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa470>,
#  'реальный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa4a8>,
#  'стимул': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa4e0>,
#  'красивый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa518>,
#  'тело': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa550>,
#  'пляжесам': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa588>,
#  'мотивация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa5c0>,
#  'приступить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa5f8>,
#  'участвовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa630>,
#  'конкурс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa668>,
#  'тнт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa6a0>,
#  'там': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa6d8>,
#  'путёвка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa710>,
#  'сейшелы': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa748>,
#  'разыгрываться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa780>,
#  'захотеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa7b8>,
#  'выиграть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa7f0>,
#  'куда': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa828>,
#  'без': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa860>,
#  'вопрос': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa898>,
#  'задаваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa8d0>,
#  'именно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa908>,
#  'мой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa940>,
#  'точка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa978>,
#  'зрение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa9b0>,
#  'здесь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aa9e8>,
#  'нужно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaa20>,
#  'рассматривать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaa58>,
#  'вторичный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaa90>,
#  'помеха': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaac8>,
#  'пример': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aab00>,
#  'практически': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aab38>,
#  'ничто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aab70>,
#  'отвлекать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaba8>,
#  'сушка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aabe0>,
#  'большой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aac18>,
#  'количество': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aac50>,
#  'праздниковновый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aac88>,
#  'год': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aacc0>,
#  'день': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aacf8>,
#  'рождение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aad30>,
#  'девушка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aad68>,
#  'хороший': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aada0>,
#  'друг': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aadd8>,
#  'родитель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aae10>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aae48>,
#  'худеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aae80>,
#  'ибо': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaeb8>,
#  'сложный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaef0>,
#  'сорваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaf28>,
#  'включаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaf60>,
#  'некий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aaf98>,
#  'мотивировать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aafd0>,
#  'сила': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad048>,
#  'под': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad080>,
#  'название': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad0b8>,
#  'лёт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad0f0>,
#  'лишь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad128>,
#  'для': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad160>,
#  'иначе': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad198>,
#  'чисто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad1d0>,
#  'логический': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad208>,
#  'организм': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad240>,
#  'запасать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad278>,
#  'жир': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad2b0>,
#  'согревание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad2e8>,
#  'эстетический': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad320>,
#  'составлять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad358>,
#  'природа': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad390>,
#  'предусмотреть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad3c8>,
#  'сохранение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad400>,
#  'тепло': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad438>,
#  'холод': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad470>,
#  'плюс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad4a8>,
#  'двигаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad4e0>,
#  'улица': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad518>,
#  'можно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad550>,
#  'кататься': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad588>,
#  'велик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad5c0>,
#  'ролик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad5f8>,
#  'просто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad630>,
#  'город': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad668>,
#  'гулять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad6a0>,
#  'грустно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad6d8>,
#  'чипсик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad710>,
#  'телик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad748>,
#  'адовый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad780>,
#  'холодина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad7b8>,
#  'гололд': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad7f0>,
#  'тп': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad828>,
#  'выйти': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad860>,
#  'температура': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad898>,
#  'понадобиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad8d0>,
#  'израсходовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad908>,
#  'хотеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad940>,
#  'начинать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad978>,
#  'сразу': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad9b0>,
#  'сейчас': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ad9e8>,
#  'посоветовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ada20>,
#  'насчта': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ada58>,
#  'сон': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ada90>,
#  'засыпание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adac8>,
#  'полюбить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adb00>,
#  'режим': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adb38>,
#  'приучить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adb70>,
#  'себя': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adba8>,
#  'ложиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adbe0>,
#  'один': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adc18>,
#  'время': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adc50>,
#  'даже': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adc88>,
#  'выходной': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adcc0>,
#  'быстро': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adcf8>,
#  'привыкнуть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31add30>,
#  'спать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31add68>,
#  'положить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adda0>,
#  'просыпаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31addd8>,
#  'оно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ade10>,
#  'тоже': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ade48>,
#  'вволю': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ade80>,
#  'поваляться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adeb8>,
#  'постель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adef0>,
#  'рассказ': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adf28>,
#  'петрушевский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adf60>,
#  'другой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adf98>,
#  'русский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31adfd0>,
#  'автор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af240>,
#  'настоящий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af0f0>,
#  'страшный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af160>,
#  'семья': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af1d0>,
#  'вурдалак': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af208>,
#  'толстой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af080>,
#  'кристмас': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af198>,
#  'гурман': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af128>,
#  'варго': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af0b8>,
#  'пожалуйста': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af048>,
#  'дать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af278>,
#  'развернуть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af2b0>,
#  'ответ': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af2e8>,
#  'интересно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af320>,
#  'читать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af358>,
#  'маленький': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af390>,
#  'знак': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af438>,
#  'сам': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af3c8>,
#  'экранизация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af4a8>,
#  'пелевинский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af400>,
#  'синий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af518>,
#  'фонарь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af470>,
#  'вполне': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af588>,
#  'жуткий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af4e0>,
#  'метафизически': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af5f8>,
#  'как': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af550>,
#  'мэтр': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af5c0>,
#  'закрываться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af630>,
#  'магазин': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af668>,
#  'продать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af6a0>,
#  'из': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af6d8>,
#  'мебель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af710>,
#  'напрашиваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af748>,
#  'авить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af780>,
#  'специализировать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af7b8>,
#  'площадка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af7f0>,
#  'продажа': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af828>,
#  'много': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af860>,
#  'реализация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af898>,
#  'товар': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af8d0>,
#  'успеть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af908>,
#  'например': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af940>,
#  'подобный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af978>,
#  'ситуация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af9b0>,
#  'катастрофически': <gensim.models.keyedvectors.Vocab at 0x7fa7f31af9e8>,
#  'поэтому': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afa20>,
#  'смочь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afa58>,
#  'реализовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afa90>,
#  'прийтись': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aff60>,
#  'банально': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afcf8>,
#  'сдать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afc88>,
#  'утилизация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afc18>,
#  'спам': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afba8>,
#  'ожидать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afcc0>,
#  'пока': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afda0>,
#  'купить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afe48>,
#  'отсылка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afeb8>,
#  'присутствовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afe10>,
#  'зелный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afe80>,
#  'слоник': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afef0>,
#  'никакой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aff28>,
#  'нет': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afd30>,
#  'зелном': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afac8>,
#  'тот': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afb00>,
#  'причина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afb38>,
#  'прописать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afb70>,
#  'сценарий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afbe0>,
#  'таковой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afd68>,
#  'актр': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afc50>,
#  'начинающий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31afdd8>,
#  'никто': <gensim.models.keyedvectors.Vocab at 0x7fa7f31aff98>,
#  'известный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31affd0>,
#  'режисср': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3208>,
#  'болтать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b30b8>,
#  'камера': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3128>,
#  'вс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3198>,
#  'придт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b31d0>,
#  'имя': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3048>,
#  'голова': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3160>,
#  'более': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b30f0>,
#  'кино': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3080>,
#  'авторский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3240>,
#  'радикальный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3278>,
#  'эксцентричный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b32b0>,
#  'взгляд': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b32e8>,
#  'басков': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3320>,
#  'состояние': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3358>,
#  'российский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3390>,
#  'армия': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b33c8>,
#  'значит': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3400>,
#  'вставить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3438>,
#  'вот': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3470>,
#  'вычурный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b34a8>,
#  'образ': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b34e0>,
#  'донести': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3518>,
#  'до': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3550>,
#  'зритель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3588>,
#  'мысль': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b35c0>,
#  'оммажа': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b35f8>,
#  'поп': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3630>,
#  'культура': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3668>,
#  'нибыть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b36a0>,
#  'лурка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b36d8>,
#  'написать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3710>,
#  'наполнить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3748>,
#  'философский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3780>,
#  'трактат': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b37b8>,
#  'древность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b37f0>,
#  'звздной': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3828>,
#  'война': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3860>,
#  'верить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3898>,
#  'глупость': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b38d0>,
#  'ли': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3908>,
#  'мыслитель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3940>,
#  'роден': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3978>,
#  'неудобный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b39b0>,
#  'раздумье': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b39e8>,
#  'поза': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3a20>,
#  'осознавать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3a58>,
#  'реальность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3a90>,
#  'необходимый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3ac8>,
#  'осознанный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3b00>,
#  'страдание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3b38>,
#  'необычный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3b70>,
#  'бытовой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3ba8>,
#  'восприятие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3be0>,
#  'обет': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3c18>,
#  'молчание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3c50>,
#  'аскетизм': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3c88>,
#  'пр': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3cc0>,
#  'мозг': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3cf8>,
#  'работать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3d30>,
#  'активно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3d68>,
#  'диван': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3da0>,
#  'комфорт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3dd8>,
#  'человек': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3e10>,
#  'мыслить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3e48>,
#  'думать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3e80>,
#  'глубокий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3eb8>,
#  'точный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3ef0>,
#  'тонкий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3f28>,
#  'проникновение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3f60>,
#  'тема': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3f98>,
#  'сущность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b3fd0>,
#  'удобство': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6438>,
#  'ведь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b62b0>,
#  'вкус': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6278>,
#  'любить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6160>,
#  'жстковать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6198>,
#  'пуховый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6320>,
#  'перина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6390>,
#  'монах': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b62e8>,
#  'неспроста': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6358>,
#  'запираться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b63c8>,
#  'келья': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6400>,
#  'уходить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b60b8>,
#  'далкий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6208>,
#  'монастырь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6240>,
#  'комфортабельный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6048>,
#  'номер': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6128>,
#  'выбор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b61d0>,
#  'засудить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6080>,
#  'насильно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b60f0>,
#  'ты': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6470>,
#  'щекотать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b64a8>,
#  'звучать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b64e0>,
#  'смешно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6518>,
#  'суть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6828>,
#  'насилие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6630>,
#  'принять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b66a0>,
#  'полиция': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6710>,
#  'заявление': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6780>,
#  'рассмеяться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b67f0>,
#  'смотреть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6860>,
#  'где': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b68d0>,
#  'жить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6b38>,
#  'рф': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b67b8>,
#  'евразэс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6748>,
#  'африканский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b66d8>,
#  'континент': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6668>,
#  'суд': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b65f8>,
#  'дойти': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b65c0>,
#  'защекотать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6588>,
#  'насмерть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6550>,
#  'факт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6898>,
#  'смерть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6908>,
#  'видимость': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6a20>,
#  'охрана': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6a90>,
#  'право': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6b00>,
#  'жизнь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6b70>,
#  'ещё': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6be0>,
#  'имитироваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6ac8>,
#  'цивилизовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6a58>,
#  'адвокат': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b69e8>,
#  'за': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b69b0>,
#  'угроза': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6f28>,
#  'прикосновение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6c50>,
#  'доказать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6cc0>,
#  'должный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6d30>,
#  'любой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6da0>,
#  'хоть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6e10>,
#  'о': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6e80>,
#  'убийство': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6dd8>,
#  'карл': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6e48>,
#  'маркс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6eb8>,
#  'фридрих': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6c18>,
#  'энгельс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6940>,
#  'обязанность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6978>,
#  'ст': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6f98>,
#  'упк': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6fd0>,
#  'произвести': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6c88>,
#  'дознание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6ba8>,
#  'поскольку': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6f60>,
#  'дознаватель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6cf8>,
#  'курс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6d68>,
#  'скорее': <gensim.models.keyedvectors.Vocab at 0x7fa7f31b6ef0>,
#  'всего': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba048>,
#  'отказный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba080>,
#  'материал': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba0b8>,
#  'отсутствие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba0f0>,
#  'событие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba128>,
#  'преступление': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba160>,
#  'закон': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba198>,
#  'возможность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba1d0>,
#  'приписать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba208>,
#  'истязание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba240>,
#  'пора': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba278>,
#  'ввести': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba2b0>,
#  'ответственность': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba2e8>,
#  'странный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba320>,
#  'постоянно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba358>,
#  'знакомый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba390>,
#  'чем': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba3c8>,
#  'ещ': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba400>,
#  'приготовить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba438>,
#  'несквика': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba470>,
#  'кроме': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba4a8>,
#  'молоко': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba4e0>,
#  'сухой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba518>,
#  'дача': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba550>,
#  'кипятить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba588>,
#  'вода': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba5c0>,
#  'замешивать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba5f8>,
#  'любитель': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba630>,
#  'вообще': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba668>,
#  'начать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba6a0>,
#  'тренажрный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba6d8>,
#  'человечек': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba710>,
#  'подсказать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba748>,
#  'рецептможный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba780>,
#  'вкусный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba7b8>,
#  'йогурт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba7f0>,
#  'ну': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba828>,
#  'коктельпонадобиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba860>,
#  'чайный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba898>,
#  'ложка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba8d0>,
#  'столовый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba908>,
#  'овсяный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba940>,
#  'каша': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba978>,
#  'грамм': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba9b0>,
#  'творог': <gensim.models.keyedvectors.Vocab at 0x7fa7f31ba9e8>,
#  'банан': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baa20>,
#  'мл': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baa58>,
#  'молокавс': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baa90>,
#  'миксер': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baac8>,
#  'получаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bab00>,
#  'очень': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bab38>,
#  'вкусно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bab70>,
#  'почему': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baba8>,
#  'чиновник': <gensim.models.keyedvectors.Vocab at 0x7fa7f31babe0>,
#  'решить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bac18>,
#  'элементарный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bac50>,
#  'проблема': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bac88>,
#  'мусор': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bacc0>,
#  'некогда': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bacf8>,
#  'культурный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bad30>,
#  'столица': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bad68>,
#  'украина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bada0>,
#  'львов': <gensim.models.keyedvectors.Vocab at 0x7fa7f31badd8>,
#  'двадцать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bae10>,
#  'привязка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bae48>,
#  'конкретный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bae80>,
#  'всм': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baeb8>,
#  'желание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baef0>,
#  'запустить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baf28>,
#  'мусороперерабатывающий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baf60>,
#  'завод': <gensim.models.keyedvectors.Vocab at 0x7fa7f31baf98>,
#  'аналогичный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bafd0>,
#  'европейский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be048>,
#  'копенгаген': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be080>,
#  'агломерация': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be0b8>,
#  'хватать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be0f0>,
#  'обычно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be128>,
#  'объясняться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be160>,
#  'силой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be198>,
#  'местный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be1d0>,
#  'сельский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be208>,
#  'громада': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be240>,
#  'защищать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be278>,
#  'среда': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be2b0>,
#  'обитание': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be2e8>,
#  'противодействие': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be320>,
#  'являться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be358>,
#  'винтик': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be390>,
#  'гигантский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be3c8>,
#  'машина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be400>,
#  'редкий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be438>,
#  'случай': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be470>,
#  'виноватый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be4a8>,
#  'горуправа': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be4e0>,
#  'разложить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be518>,
#  'атом': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be550>,
#  'верно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be588>,
#  'существующий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be5c0>,
#  'формат': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be5f8>,
#  'либо': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be630>,
#  'сохранять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be668>,
#  'статус': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be6a0>,
#  'кво': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be6d8>,
#  'вывозить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be710>,
#  'тонна': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be748>,
#  'свалка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be780>,
#  'сегодняшний': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be7b8>,
#  'переполнить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be7f0>,
#  'закрытый': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be828>,
#  'менять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be860>,
#  'пытаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be898>,
#  'крайний': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be8d0>,
#  'мера': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be908>,
#  'единственный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be940>,
#  'решение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be978>,
#  'становиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be9b0>,
#  'сортировка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31be9e8>,
#  'пилотный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bea20>,
#  'проект': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bea58>,
#  'в': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bea90>,
#  'уж': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beac8>,
#  'львовский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beb00>,
#  'власть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beb38>,
#  'грешить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beb70>,
#  'благоустройство': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beba8>,
#  'неправильно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bebe0>,
#  'сравнивать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bec18>,
#  'украинский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bec50>,
#  'выстраивать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bec88>,
#  'взаимоотношение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31becc0>,
#  'разный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31becf8>,
#  'бывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bed30>,
#  'дружеский': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bed68>,
#  'любовный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beda0>,
#  'рабочий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bedd8>,
#  'поточный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bee10>,
#  'общий': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bee48>,
#  'картина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bee80>,
#  'отвечать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beeb8>,
#  'деликатно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31beef0>,
#  'искренне': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bef28>,
#  'гарри': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bef60>,
#  'поттер': <gensim.models.keyedvectors.Vocab at 0x7fa7f31bef98>,
#  'упоминаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31befd0>,
#  'рон': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141048>,
#  'гермиона': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141080>,
#  'книга': <gensim.models.keyedvectors.Vocab at 0x7fa7f31410b8>,
#  'почти': <gensim.models.keyedvectors.Vocab at 0x7fa7f31410f0>,
#  'хотя': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141128>,
#  'праздноваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141160>,
#  'течение': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141198>,
#  'учебный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31411d0>,
#  'март': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141208>,
#  'сентябрь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141240>,
#  'главный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141278>,
#  'герой': <gensim.models.keyedvectors.Vocab at 0x7fa7f31412b0>,
#  'праздник': <gensim.models.keyedvectors.Vocab at 0x7fa7f31412e8>,
#  'иметь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141320>,
#  'смысл': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141358>,
#  'описывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141390>,
#  'двигать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31413c8>,
#  'сюжет': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141400>,
#  'вперд': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141438>,
#  'новый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141470>,
#  'причм': <gensim.models.keyedvectors.Vocab at 0x7fa7f31414a8>,
#  'чаща': <gensim.models.keyedvectors.Vocab at 0x7fa7f31414e0>,
#  'происходить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141518>,
#  'важный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141550>,
#  'волшебник': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141588>,
#  'узнать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31415c0>,
#  'исполниться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31415f8>,
#  'лишиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141630>,
#  'защита': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141668>,
#  'матерь': <gensim.models.keyedvectors.Vocab at 0x7fa7f31416a0>,
#  'кстати': <gensim.models.keyedvectors.Vocab at 0x7fa7f31416d8>,
#  'джоана': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141710>,
#  'роулинга': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141748>,
#  'июль': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141780>,
#  'возможно': <gensim.models.keyedvectors.Vocab at 0x7fa7f31417b8>,
#  'съесть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31417f0>,
#  'целовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141828>,
#  'банка': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141860>,
#  'корица': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141898>,
#  'маловероятный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31418d0>,
#  'уточнить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141908>,
#  'размер': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141940>,
#  'жестяной': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141978>,
#  'баночка': <gensim.models.keyedvectors.Vocab at 0x7fa7f31419b0>,
#  'кофе': <gensim.models.keyedvectors.Vocab at 0x7fa7f31419e8>,
#  'обычный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141a20>,
#  'литровый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141a58>,
#  'трхлитровый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141a90>,
#  'абсолютно': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141ac8>,
#  'продукт': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141b00>,
#  'три': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141b38>,
#  'четыре': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141b70>,
#  'успех': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141ba8>,
#  'идея': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141be0>,
#  'больший': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141c18>,
#  'нанести': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141c50>,
#  'вред': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141c88>,
#  'здоровье': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141cc0>,
#  'проверять': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141cf8>,
#  'рекомендовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141d30>,
#  'рассказать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141d68>,
#  'система': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141da0>,
#  'образование': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141dd8>,
#  'австрииконкретный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3141e10>,
# ...
#  'учтом': <gensim.models.keyedvectors.Vocab at 0x7fa7f31455c0>,
#  'комплексный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31455f8>,
#  'показатель': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145630>,
#  'заводить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145668>,
#  'ребёнок': <gensim.models.keyedvectors.Vocab at 0x7fa7f31456a0>,
#  'подать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31456d8>,
#  'ответить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145710>,
#  'немного': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145748>,
#  'старое': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145780>,
#  'анекдот': <gensim.models.keyedvectors.Vocab at 0x7fa7f31457b8>,
#  'стакан': <gensim.models.keyedvectors.Vocab at 0x7fa7f31457f0>,
#  'старость': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145828>,
#  'принесть': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145860>,
#  'слуга': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145898>,
#  'представить': <gensim.models.keyedvectors.Vocab at 0x7fa7f31458d0>,
#  'вырасти': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145908>,
#  'закончить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145940>,
#  'школа': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145978>,
#  'решать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31459b0>,
#  'зарплата': <gensim.models.keyedvectors.Vocab at 0x7fa7f31459e8>,
#  'тут': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145a20>,
#  'ручка': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145a58>,
#  'говорятсынок': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145a90>,
#  'вырастить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145ac8>,
#  'подносить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145b00>,
#  'понравиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145b38>,
#  'пользоваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145b70>,
#  'ребнкома': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145ba8>,
#  'вещь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145be0>,
#  'родить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145c18>,
#  'далёкий': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145c50>,
#  'помогать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145c88>,
#  'заняться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145cc0>,
#  'точно': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145cf8>,
#  'уметь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145d30>,
#  'кухня': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145d68>,
#  'водичка': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145da0>,
#  'робот': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145dd8>,
#  'умный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145e10>,
#  'справиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145e48>,
#  'задача': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145e80>,
#  'подвижность': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145eb8>,
#  'взять': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145ef0>,
#  'большинство': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145f28>,
#  'современный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145f60>,
#  'мужчина': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145f98>,
#  'россия': <gensim.models.keyedvectors.Vocab at 0x7fa7f3145fd0>,
#  'доживать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147048>,
#  'возраст': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147080>,
#  'подавать': <gensim.models.keyedvectors.Vocab at 0x7fa7f31470b8>,
#  'инфаркт': <gensim.models.keyedvectors.Vocab at 0x7fa7f31470f0>,
#  'инсульт': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147128>,
#  'косить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147160>,
#  'мужик': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147198>,
#  'женщина': <gensim.models.keyedvectors.Vocab at 0x7fa7f31471d0>,
#  'статистика': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147208>,
#  'гуманный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147240>,
#  'ласковый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147278>,
#  'получиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31472b0>,
#  'дотянуть': <gensim.models.keyedvectors.Vocab at 0x7fa7f31472e8>,
#  'пенсия': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147320>,
#  'соцопека': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147358>,
#  'помочь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147390>,
#  'водоснабжение': <gensim.models.keyedvectors.Vocab at 0x7fa7f31473c8>,
#  'каков': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147400>,
#  'качалка': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147438>,
#  'приходить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147470>,
#  'выполнять': <gensim.models.keyedvectors.Vocab at 0x7fa7f31474a8>,
#  'тренер': <gensim.models.keyedvectors.Vocab at 0x7fa7f31474e0>,
#  'определённый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147518>,
#  'упражнение': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147550>,
#  'потом': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147588>,
#  'зал': <gensim.models.keyedvectors.Vocab at 0x7fa7f31475c0>,
#  'редко': <gensim.models.keyedvectors.Vocab at 0x7fa7f31475f8>,
#  'пришлый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147630>,
#  'туда': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147668>,
#  'познакомиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31476a0>,
#  'нормальный': <gensim.models.keyedvectors.Vocab at 0x7fa7f31476d8>,
#  'недалеко': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147710>,
#  'старый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147748>,
#  'древние': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147780>,
#  'мужской': <gensim.models.keyedvectors.Vocab at 0x7fa7f31477b8>,
#  'тренажёр': <gensim.models.keyedvectors.Vocab at 0x7fa7f31477f0>,
#  'фотография': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147828>,
#  'качковы': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147860>,
#  'начало': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147898>,
#  'назад': <gensim.models.keyedvectors.Vocab at 0x7fa7f31478d0>,
#  'тогда': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147908>,
#  'неловко': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147940>,
#  'неуютный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147978>,
#  'втянуться': <gensim.models.keyedvectors.Vocab at 0x7fa7f31479b0>,
#  'заниматься': <gensim.models.keyedvectors.Vocab at 0x7fa7f31479e8>,
#  'преимущественно': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147a20>,
#  'утро': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147a58>,
#  'казалось': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147a90>,
#  'толща': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147ac8>,
#  'встречать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147b00>,
#  'хыхых': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147b38>,
#  'теперь': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147b70>,
#  'весить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147ba8>,
#  'килограмм': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147be0>,
#  'рост': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147c18>,
#  'сантиметр': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147c50>,
#  'сбросить': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147c88>,
#  'питание': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147cc0>,
#  'измениться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147cf8>,
#  'значительно': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147d30>,
#  'стать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147d68>,
#  'калория': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147da0>,
#  'обходиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147dd8>,
#  'ночное': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147e10>,
#  'зажор': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147e48>,
#  'перестать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147e80>,
#  'сутулиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147eb8>,
#  'выносливый': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147ef0>,
#  'энергичный': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147f28>,
#  'тренировка': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147f60>,
#  'вставать': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147f98>,
#  'стоимость': <gensim.models.keyedvectors.Vocab at 0x7fa7f3147fd0>,
#  'абонемент': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c048>,
#  'индивидуальный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c080>,
#  'вложение': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c0b8>,
#  'ожидание': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c0f0>,
#  'влиять': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c128>,
#  'результат': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c160>,
#  'часто': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c198>,
#  'достигаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c1d0>,
#  'особо': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c208>,
#  'рассчитывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c240>,
#  'эксперимент': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c278>,
#  'находиться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c2b0>,
#  'прямая': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c2e8>,
#  'зависимость': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c320>,
#  'условие': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c358>,
#  'личность': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c390>,
#  'экспериментатор': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c3c8>,
#  'постулат': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c400>,
#  'физик': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c438>,
#  'очевидный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c470>,
#  'появление': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c4a8>,
#  'квантовый': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c4e0>,
#  'механика': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c518>,
#  'проведение': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c550>,
#  'щелевой': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c588>,
#  'лирик': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c5c0>,
#  'наоборот': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c5f8>,
#  'понятие': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c630>,
#  'эффект': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c668>,
#  'самоисполняться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c6a0>,
#  'пророчество': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c6d8>,
#  'положительно': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c710>,
#  'счт': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c748>,
#  'бессознательно': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c780>,
#  'продвигать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c7b8>,
#  'ложный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c7f0>,
#  'невозможный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c828>,
#  'информация': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c860>,
#  'шутка': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c898>,
#  'интернет': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c8d0>,
#  'называть': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c908>,
#  'баян': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c940>,
#  'связать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c978>,
#  'древнерусский': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c9b0>,
#  'сказитель': <gensim.models.keyedvectors.Vocab at 0x7fa7f314c9e8>,
#  'боян': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ca20>,
#  'выражение': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ca58>,
#  'произойти': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ca90>,
#  'хоронить': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cac8>,
#  'тщу': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cb00>,
#  'порвать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cb38>,
#  'два': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cb70>,
#  'настолько': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cba8>,
#  'публиковаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cbe0>,
#  'пользователь': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cc18>,
#  'форум': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cc50>,
#  'нарицательный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cc88>,
#  'заездить': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ccc0>,
#  'значение': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ccf8>,
#  'ушл': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cd30>,
#  'масса': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cd68>,
#  'следовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cda0>,
#  'путать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cdd8>,
#  'бородатый': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ce10>,
#  'классика': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ce48>,
#  'выяснить': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ce80>,
#  'расхожий': <gensim.models.keyedvectors.Vocab at 0x7fa7f314ceb8>,
#  'слишком': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cef0>,
#  'слушатель': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cf28>,
#  'мем': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cf60>,
#  'пройти': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cf98>,
#  'пик': <gensim.models.keyedvectors.Vocab at 0x7fa7f314cfd0>,
#  'медийный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f048>,
#  'активность': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f080>,
#  'пойти': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f0b8>,
#  'убыль': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f0f0>,
#  'новость': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f128>,
#  'рука': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f160>,
#  'слоупока': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f198>,
#  'жанр': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f1d0>,
#  'претендовать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f208>,
#  'принадлежность': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f240>,
#  'крылатый': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f278>,
#  'распространнный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f2b0>,
#  'типовой': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f2e8>,
#  'фразеологизм': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f320>,
#  'угодный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f358>,
#  'использоваться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f390>,
#  'место': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f3c8>,
#  'назначение': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f400>,
#  'считаться': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f438>,
#  'ознакомление': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f470>,
#  'детство': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f4a8>,
#  'навсегда': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f4e0>,
#  'альтернативный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f518>,
#  'одарнный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f550>,
#  'рассказывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f588>,
#  'качество': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f5c0>,
#  'прийти': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f5f8>,
#  'назвать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f630>,
#  'уместный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f668>,
#  'упоминание': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f6a0>,
#  'наконец': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f6d8>,
#  'совсем': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f710>,
#  'третье': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f748>,
#  'явление': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f780>,
#  'годный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f7b8>,
#  'хорошо': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f7f0>,
#  'забыть': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f828>,
#  'очередной': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f860>,
#  'всплывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f898>,
#  'веселить': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f8d0>,
#  'нубова': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f908>,
#  'иногда': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f940>,
#  'повторно': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f978>,
#  'побывать': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f9b0>,
#  'эпик': <gensim.models.keyedvectors.Vocab at 0x7fa7f314f9e8>,
#  'вино': <gensim.models.keyedvectors.Vocab at 0x7fa7f314fa20>,
#  'профильный': <gensim.models.keyedvectors.Vocab at 0x7fa7f314fa58>,
#  'уютненький': <gensim.models.keyedvectors.Vocab at 0x7fa7f314fa90>,
#  ...}

# %%
w2v.most_similar(['король', 'женщина'], ['мужчина'])
# Out:
# /home/v.gulin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /home/v.gulin/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('князь', 0.8170202970504761),
#  ('де', 0.7870656251907349),
#  ('ii', 0.7804590463638306),
#  ('iii', 0.7776327133178711),
#  ('грозный', 0.7769745588302612),
#  ('ленин', 0.775465190410614),
#  ('николай', 0.7737562656402588),
#  ('борис', 0.7711115479469299),
#  ('джон', 0.7696213722229004),
#  ('королева', 0.7678171992301941)]

# %%
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
class QuestionVectorizer(nn.Module):
    def __init__(self, n_tokens=len(tokens), out_size=64, use_global_emb=True):
        """ 
        A simple sequential encoder for questions.
        Use any combination of layers you want to encode a variable-length input 
        to a fixed-size output vector
        """
        super(self.__class__, self).__init__()
        
        """<PUT YOUR CODE HERE>"""
        
    def forward(self, text_ix):
        """
        :param text_ix: int64 Variable of shape [batch_size, max_len]
        :returns: float32 Variable of shape [batch_size, out_size]
        """
        """<PUT YOUR CODE HERE>"""

# %%
class AnswerVectorizer(nn.Module):
    def __init__(self, n_tokens=len(tokens), out_size=64, use_global_emb=True):
        """ 
        A simple sequential encoder for answers.
        x -> emb -> conv -> global_max -> relu -> dense
        
        If use_global_emb is True, use GLOBAL_EMB as your embedding layer
        """
        super(self.__class__, self).__init__()
        """<PUT YOUR CODE HERE>"""
        
    def forward(self, text_ix):
        """
        :param text_ix: int64 Variable of shape [batch_size, max_len]
        :returns: float32 Variable of shape [batch_size, out_size]
        """
        """<PUT YOUR CODE HERE>"""

# %%
test = as_matrix(["В какой стране статистически больше всего левшей? Существует ли страна/город, в котором левшей больше чем правшей?", "Говорят, в ЮАР около 50% населения - левши, возможно и больше 50%, а возможно и меньше."])
print(test)
# Out:
# [[   93    63 19241   196   456 16748  2413  1027     1     4 16748   196
#    1004 10236]
#  [ 1422  4196  1921  1769 16748   704   196   704   283     0     0     0
#       0     0]]

# %%
for vectorizer in [QuestionVectorizer(out_size=100), AnswerVectorizer(out_size=100)]:
    print("Testing %s ..." % vectorizer.__class__.__name__)
    dummy_x = Variable(torch.LongTensor(test))
    dummy_v = vectorizer(dummy_x)

    assert isinstance(dummy_v, Variable)
    assert tuple(dummy_v.shape) == (dummy_x.shape[0], 100)

    del vectorizer
    print("Seems fine")

# %%
from itertools import chain

question_vectorizer = QuestionVectorizer()
answer_vectorizer = AnswerVectorizer()

opt = torch.optim.Adam(chain(question_vectorizer.parameters(),
                             answer_vectorizer.parameters()))
# Out:
# 1

# %%
def generate_batch(data, batch_size=None, replace=False, volatile=False, max_len=None):
    """ Samples training/validation batch with random negatives """
    if batch_size is not None:
        batch_ix = np.random.choice(len(data), batch_size, replace=replace)
        negative_ix = np.random.choice(len(data), batch_size, replace=True)
    else:
        batch_ix = range(len(data))
        negative_ix = np.random.permutation(np.arange(len(data)))

    
    anchors, positives = zip(*[data[i] for i in batch_ix])
    
    # sample random rows as negatives.
    # Note: you can do better by sampling "hard" negatives
    negatives = [data[i][1] for i in negative_ix]
    
    anchors, positives, negatives = map(lambda x: Variable(torch.LongTensor(as_matrix(x, max_len=max_len)),
                                                           volatile=volatile), 
                                        [anchors, positives, negatives])
    return anchors, positives, negatives

# %%
def build_dataset(train_data):
    '''Takes data
    Returns a list of tuples - a set of pairs (q, a_+)
    '''
    dataset = []
    for row in tqdm_notebook(train_data):
        question, answer = row['question'], row['answers'][0]
        dataset.append((question, answer))
        
    return dataset

# %%
train_data = build_dataset(questions_train)
# Out:
# HBox(children=(IntProgress(value=0, max=52143), HTML(value='')))

# %%
_dummy_anchors, _dummy_positives, _dummy_negatives = generate_batch(train_data, 2)

# %%
def compute_loss(anchors, positives, negatives, delta=3):
    """ 
    Compute the triplet loss:
    
    max(0, delta + sim(anchors, negatives) - sim(anchors, positives))
    
    where sim is a dot-product between vectorized inputs
    
    """
    
    """<PUT YOUR CODE HERE>"""

# %%
print(compute_loss(_dummy_anchors, _dummy_positives, _dummy_negatives))

# %%
num_epochs = 100
max_len = 100
batch_size = 32
batches_per_epoch = 100

# %%
def iterate_minibatches(data, batch_size=32, max_len=None,
                        max_batches=None, shuffle=True, verbose=True):
    indices = np.arange(len(data))
    if shuffle:
        indices = np.random.permutation(indices)
    if max_batches is not None:
        indices = indices[: batch_size * max_batches]
        
    irange = tnrange if verbose else range
    
    for start in irange(0, len(indices), batch_size):
        yield generate_batch([data[i] for i in indices[start : start + batch_size]], max_len=max_len)

# %%
for epoch_i in range(num_epochs):
    
    print("Training:")
    train_loss = train_mae = train_batches = 0    
    
    for batch in iterate_minibatches(train_data, max_batches=batches_per_epoch, batch_size=512):
        

        loss = compute_loss(*batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        

        train_loss += loss.data.cpu().numpy()
        train_batches += 1
    
    print("\tLoss:\t%.5f" % (train_loss / train_batches))
    print('\n\n')
